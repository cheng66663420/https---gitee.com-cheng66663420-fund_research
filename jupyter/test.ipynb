# %%
import datetime

import pandas as pd
import polars as pl

import quant_utils.data_moudle as dm
from data_functions.portfolio_data import get_portfolio_info, query_portfolio_nav
from quant_utils.constant import DATE_FORMAT, DB_CONFIG, TODAY
from quant_utils.constant_varialbles import LAST_TRADE_DT
from quant_utils.db_conn import DB_CONN_JJTG_DATA
from quant_utils.send_email import MailSender

RENAME_DICT = {
    "TICKER_SYMBOL": "组合名称",
    "CYCLE": "周期",
    "START_DATE": "起始日期",
    "END_DATE": "结束日期",
    "INDICATOR": "指标",
    "PORTFOLIO_VALUE": "组合",
    "PEER_RANK": "同类基金排名",
    "BENCHMARK_VALUE_OUTTER": "对客基准",
    "BENCHMARK_VALUE_INNER": "对内基准",
    "PEER_MEDIAN": "同类中位数",
    "PEER_FOF_RANK": "同类FOF排名",
    "PEER_PORTFOLIO_RANK": "同类投顾排名",
}

USED_COLUMNS = [
    "TICKER_SYMBOL", 
    "PORTFOLIO_NAME",
    "START_DATE", 
    "END_DATE", 
    "INDICATOR",
]

def crate_database_uri(database_type: str, config: dict) -> str:
    return f"{database_type}://{config['user']}:{config['pwd']}@{config['host']}:{config['port']}/{config['database']}"


JJTF_URI = crate_database_uri("mysql", DB_CONFIG["jjtg"])


def unpivot_dataframe(df: pl.LazyFrame) -> pl.LazyFrame:
    """
    数据透视表转置
    """
    return df.unpivot(
        index=["TICKER_SYMBOL", "PORTFOLIO_NAME","START_DATE", "END_DATE"],
        variable_name="INDICATOR",
        value_name="PORTFOLIO_VALUE",
        on=[
            "CUM_RETURN",
            "ANNUAL_RETURN",
            "ANNUAL_VOLATILITY",
            "SHARP_RATIO_ANNUAL",
            "CALMAR_RATIO_ANNUAL",
            "MAXDD",
        ],
    )

def get_portfolio_performance(
    end_date: str,
    table_name: str,
) -> pl.LazyFrame:
    query_sql = f"""
    SELECT
        TICKER_SYMBOL,
        TICKER_SYMBOL as PORTFOLIO_NAME,
        START_DATE,
        END_DATE,
        CUM_RETURN,
        ANNUAL_RETURN,
        ANNUAL_VOLATILITY,
        SHARP_RATIO_ANNUAL,
        CALMAR_RATIO_ANNUAL,
        MAXDD
    FROM
        {table_name} 
    WHERE
        1 = 1
        AND END_DATE = '{end_date}'
    """
    return pl.read_database_uri(query_sql, uri=JJTF_URI).lazy().pipe(unpivot_dataframe)


def get_peer_fund_performance(
    end_date: str,
) -> pl.LazyFrame:
    peer_query_df = (
        dm.get_portfolio_info()[["PORTFOLIO_NAME", "PEER_QUERY"]]
    )
    query_sql = f"""
        SELECT
            a.TICKER_SYMBOL,
            a.START_DATE,
            a.END_DATE,
            a.CUM_RETURN,
            a.ANNUAL_RETURN,
            a.ANNUAL_VOLATILITY,
            a.SHARP_RATIO_ANNUAL,
            a.CALMAR_RATIO_ANNUAL,
            a.MAXDD,
            c.LEVEL_1,
            c.LEVEL_2,
            c.LEVEL_3,
            c.EQUITY_RATIO_IN_NA,
            c.SEC_SHORT_NAME
        FROM
            fund_performance_inner a
            JOIN fund_type_own c ON c.TICKER_SYMBOL = a.TICKER_SYMBOL
        WHERE
            1 = 1 
            AND a.END_DATE = '{end_date}' 
            AND ( 
                c.REPORT_DATE = ( 
                    SELECT max( report_date ) 
                    FROM fund_type_own 
                    WHERE PUBLISH_DATE <= '{end_date}' 
                )
            )
        """
    fund_perf = pl.read_database_uri(query_sql, uri=JJTF_URI).lazy()
    result_list = []
    for _, val in peer_query_df.iterrows():
        peer_query = val["PEER_QUERY"]
        peer_query = peer_query.replace("==", "=")
        peer_query = peer_query.replace('"', "'")
        peer_query_sql = f""" 
            select 
                TICKER_SYMBOL,
                START_DATE,
                END_DATE,
                CUM_RETURN,
                ANNUAL_RETURN,
                ANNUAL_VOLATILITY,
                SHARP_RATIO_ANNUAL,
                CALMAR_RATIO_ANNUAL,
                MAXDD
            from
                self
            where {peer_query}
        """
        temp = (
            fund_perf.sql(peer_query_sql)
            .with_columns(pl.lit(val["PORTFOLIO_NAME"]).alias("PORTFOLIO_NAME"))
            .pipe(unpivot_dataframe)
        )
        result_list.append(temp)
    return pl.concat(result_list)

def get_peer_fof_performance(
    end_date: str,
) -> pl.LazyFrame:
    query_sql = f"""
    SELECT
        a.TICKER_SYMBOL,
        c.INNER_TYPE as PORTFOLIO_NAME,
        a.START_DATE,
        a.END_DATE,
        a.CUM_RETURN,
        a.ANNUAL_RETURN,
        a.ANNUAL_VOLATILITY,
        a.SHARP_RATIO_ANNUAL,
        a.CALMAR_RATIO_ANNUAL,
        a.MAXDD 
    FROM
        fund_performance_inner a
        JOIN fof_type c ON c.TICKER_SYMBOL = a.TICKER_SYMBOL 
    WHERE
        1 = 1 
        AND a.END_DATE = '{end_date}' 
    """
    return pl.read_database_uri(query_sql, uri=JJTF_URI).lazy().pipe(unpivot_dataframe)

def get_peer_portfolio_performance(
    end_date: str,
)-> pl.LazyFrame:
    query_sql = f"""
    SELECT
        a.TICKER_SYMBOL,
        c.PORTFOLIO_TYPE as PORTFOLIO_NAME,
        a.START_DATE,
        a.END_DATE,
        a.CUM_RETURN,
        a.ANNUAL_RETURN,
        a.ANNUAL_VOLATILITY,
        a.SHARP_RATIO_ANNUAL,
        a.CALMAR_RATIO_ANNUAL,
        a.MAXDD 
    FROM
        peer_performance_inner a
        JOIN peer_portfolio_type c ON c.TICKER_SYMBOL = a.TICKER_SYMBOL 
    WHERE
        1 = 1 
        AND a.END_DATE = '{end_date}' 
    """
    return (
        pl.read_database_uri(query_sql, uri=JJTF_URI)
        .lazy()
        .pipe(unpivot_dataframe)
    )

def get_benchmark_value_outter(end_date: str) -> pl.lazyframe:
    query = f"""
    SELECT
        a.TICKER_SYMBOL,
        a.START_DATE,
        a.END_DATE,
        a.CUM_RETURN,
        a.ANNUAL_RETURN,
        a.ANNUAL_VOLATILITY,
        a.SHARP_RATIO_ANNUAL,
        a.CALMAR_RATIO_ANNUAL,
        a.MAXDD 
    FROM
        benchmark_performance_inner a
    WHERE
        1 = 1 
        AND a.END_DATE = '{end_date}' 
    """
    df = pl.read_database_uri(query, uri=JJTF_URI).lazy()
    df_unpivot = df.unpivot(
        index=["TICKER_SYMBOL", "START_DATE", "END_DATE"],
        variable_name="INDICATOR",
        value_name="BENCHMARK_VALUE_OUTTER",
    )
    return df_unpivot


def rank_pct(
    rank_col: str, patition_by: str | list = None, descending: bool = True
) -> pl.Expr:
    rank_expr = pl.col(rank_col).rank(descending=descending).cast(pl.UInt32)
    count_expr = pl.col(rank_col).count().cast(pl.UInt32)
    return 100 * ((rank_expr - 1) / (count_expr - 1)).over(patition_by)


def rank_str(
    rank_col: str, patition_by: str | list = None, descending: bool = True
) -> pl.Expr:
    rank_expr = pl.col(rank_col).rank(descending=descending).cast(pl.UInt32)
    count_expr = pl.col(rank_col).count().cast(pl.UInt32)
    return (
        rank_expr.cast(pl.String).over(patition_by)
        + "/"
        + count_expr.cast(pl.String).over(patition_by)
    )


def _cal_performance_rank_helper(
    df: pl.LazyFrame,
    patition_by: str | list = None,
    incicator_list: list = None,
    descending: bool = True,
) -> pl.LazyFrame:
    # 计算排名及百分位
    # 特别注意在polars中rank函数不考虑空值
    result_df = (
        df.select(
            [
                pl.col("TICKER_SYMBOL"),
                pl.col("PORTFOLIO_NAME"),
                pl.col("START_DATE"),
                pl.col("END_DATE"),
                pl.col("INDICATOR"),
                pl.col("PORTFOLIO_VALUE"),
            ]
        )
        .filter(pl.col("INDICATOR").is_in(incicator_list))
        .with_columns(
            rank_pct(
                "PORTFOLIO_VALUE", patition_by=patition_by, descending=descending
            ).alias("PEER_RANK_PCT"),
            rank_str(
                "PORTFOLIO_VALUE", patition_by=patition_by, descending=descending
            ).alias("PEER_RANK"),
        )
    )

    return result_df


def cal_performance_rank(df: pl.LazyFrame) -> pl.LazyFrame:
    asscending_indicators = ["MAXDD", "ANNUAL_VOLATILITY",]
    descending_indicators = [
        "CUM_RETURN",
        "ANNUAL_RETURN",
        "SHARP_RATIO_ANNUAL",
        "CALMAR_RATIO_ANNUAL",
    ]
    patition_by = ["PORTFOLIO_NAME", "START_DATE", "END_DATE", "INDICATOR",]
    # 计算排名及百分位
    # 特别注意在polars中rank函数不考虑空值
    df_asscending = _cal_performance_rank_helper(
        df,
        patition_by=patition_by,
        incicator_list=asscending_indicators,
        descending=False,
    )

    df_descending = _cal_performance_rank_helper(
        df,
        patition_by=patition_by,
        incicator_list=descending_indicators,
        descending=True,
    )
    result = pl.concat([df_asscending, df_descending]).filter(
        pl.col("TICKER_SYMBOL") == pl.col("PORTFOLIO_NAME")
    )
    return result

def get_portfolio_dates(end_date: str) -> pl.LazyFrame:
    query_sql = f"""
    SELECT
        DATE_NAME AS CYCLE,
        PORTFOLIO_NAME as FLAG,
        START_DATE,
        END_DATE 
    FROM
        portfolio_dates 
    WHERE
        1 = 1 
        AND END_DATE = '{end_date}'
    """
    return pl.read_database_uri(query_sql, uri=JJTF_URI).lazy()


def rename_indicator_col_into_chinese(df: pl.LazyFrame):
    indicator_map_dict = {
        "CUM_RETURN": "累计收益率",
        "ANNUAL_RETURN": "年化收益率",
        "ANNUAL_VOLATILITY": "年化波动率",
        "SHARP_RATIO_ANNUAL": "收益波动比",
        "CALMAR_RATIO_ANNUAL": "年化收益回撤比",
        "MAXDD": "最大回撤",
    }
    return df.with_columns(
        pl.col("INDICATOR").replace(indicator_map_dict).alias("INDICATOR")
    )

def add_benchmark_value_otter(
    df: pl.LazyFrame,  end_date: str
) -> pl.LazyFrame:
    benchmark_df = get_benchmark_value_outter(end_date)
    result = df.join(
        benchmark_df,
        on=["TICKER_SYMBOL", "START_DATE", "END_DATE", "INDICATOR"],
        how="left",
    )

    return result


def add_peer_fof_performance(
    df: pl.LazyFrame,  end_date: str
) -> pl.LazyFrame:
    peer_fof = get_peer_fof_performance( end_date)
    result = cal_performance_rank(pl.concat([df, peer_fof]))
    result = result.rename(
        {"PEER_RANK_PCT": "PEER_FOF_RANK_PCT", "PEER_RANK": "PEER_FOF_RANK"}
    )
    result = result.select(
        USED_COLUMNS + ["PEER_FOF_RANK_PCT", "PEER_FOF_RANK"]
    )
    return df.join(
        result, on=USED_COLUMNS, how="left"
    )


def add_peer_portfolio_performance(
    df: pl.LazyFrame,  end_date: str
) -> pl.LazyFrame:
    peer_portfolio = get_peer_portfolio_performance( end_date)
    result = cal_performance_rank(pl.concat([df, peer_portfolio]))
    result = result.rename(
        {"PEER_RANK_PCT": "PEER_PORTFOLIO_RANK_PCT", "PEER_RANK": "PEER_PORTFOLIO_RANK"}
    )
    result = result.select(
        USED_COLUMNS + ["PEER_PORTFOLIO_RANK_PCT", "PEER_PORTFOLIO_RANK",]
    )
    return df.join(
        result, on=USED_COLUMNS, how="left"
    )


def cal_peer_median(peer_fund_performance: pl.LazyFrame) -> pl.LazyFrame:
    peer_median = peer_fund_performance.group_by(
        ["PORTFOLIO_NAME", "START_DATE", "END_DATE", "INDICATOR"]
    ).agg(pl.col("PORTFOLIO_VALUE").median().alias("PEER_MEDIAN"))
    return peer_median


def _cal_portfolio_performance(
    end_date: str, table_name: str
) -> pl.LazyFrame:
    portfolio_perf = get_portfolio_performance(end_date, table_name)

    peer_fund_performance = get_peer_fund_performance(end_date)

    peer_median = cal_peer_median(peer_fund_performance)

    df = pl.concat([portfolio_perf, peer_fund_performance])
    perf_rank = cal_performance_rank(df).join(
        peer_median, 
        on=["PORTFOLIO_NAME", "START_DATE", "END_DATE", "INDICATOR"], 
        how="left"
    )
    return perf_rank


def get_portfolio_derivatives_rank(end_date: str):
    portfolio_dates = get_portfolio_dates(end_date)
    perf_rank = _cal_portfolio_performance(
        end_date, "portfolio_derivatives_performance_inner"
    )
    perf_rank = (
        perf_rank.pipe(add_benchmark_value_otter, end_date)
        .rename({"BENCHMARK_VALUE_OUTTER": "BENCHMARK_VALUE_INNER"})
        .pipe(rename_indicator_col_into_chinese)
    )
    result = (
        portfolio_dates
        .join(perf_rank, on=["START_DATE", "END_DATE"])
        .filter(
            (pl.col("PORTFOLIO_NAME") == pl.col("FLAG"))
            | (pl.col("FLAG") == "ALL")
        )
        .select(pl.all().exclude(["FLAG", "PORTFOLIO_NAME"]))
    )
    return result


def get_portfolio_rank(end_date: str):
    portfolio_dates = get_portfolio_dates( end_date)
    perf_rank = _cal_portfolio_performance(
        end_date, "portfolio_performance_inner"
    )
    perf_rank = (
        perf_rank.pipe(add_benchmark_value_otter,  end_date)
        .pipe(add_peer_fof_performance,  end_date)
        # .pipe(add_peer_portfolio_performance,  end_date)
        # .pipe(rename_indicator_col_into_chinese)
    )
    result = (
        portfolio_dates
        .join(perf_rank, on=["START_DATE", "END_DATE"])
        .filter(
            (pl.col("PORTFOLIO_NAME") == pl.col("FLAG"))
            | (pl.col("FLAG") == "ALL")
        )
        .select(pl.all().exclude(["FLAG", "PORTFOLIO_NAME"]))
    )
    return result

# %%
get_portfolio_rank("2024-11-22").collect()
# Out:
# shape: (1_560, 12)
# ┌────────┬────────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ CYCLE  ┆ START_DATE ┆ END_DATE   ┆ TICKER_SY ┆ … ┆ PEER_MEDI ┆ BENCHMARK ┆ PEER_FOF_ ┆ PEER_FOF_ │
# │ ---    ┆ ---        ┆ ---        ┆ MBOL      ┆   ┆ AN        ┆ _VALUE_OU ┆ RANK_PCT  ┆ RANK      │
# │ str    ┆ date       ┆ date       ┆ ---       ┆   ┆ ---       ┆ TTER      ┆ ---       ┆ ---       │
# │        ┆            ┆            ┆ str       ┆   ┆ f64       ┆ ---       ┆ f64       ┆ str       │
# │        ┆            ┆            ┆           ┆   ┆           ┆ f64       ┆           ┆           │
# ╞════════╪════════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 对客日 ┆ 2023-03-22 ┆ 2024-11-22 ┆ 兴证全明  ┆ … ┆ 21.813618 ┆ 18.682019 ┆ NaN       ┆ 1/1       │
# │        ┆            ┆            ┆ 星精选-蚂 ┆   ┆           ┆           ┆           ┆           │
# │        ┆            ┆            ┆ 蚁        ┆   ┆           ┆           ┆           ┆           │
# │ 成立日 ┆ 2023-03-22 ┆ 2024-11-22 ┆ 兴证全明  ┆ … ┆ 21.813618 ┆ 18.682019 ┆ NaN       ┆ 1/1       │
# │        ┆            ┆            ┆ 星精选-蚂 ┆   ┆           ┆           ┆           ┆           │
# │        ┆            ┆            ┆ 蚁        ┆   ┆           ┆           ┆           ┆           │
# │ 近1年  ┆ 2023-11-22 ┆ 2024-11-22 ┆ 兴证全明  ┆ … ┆ 24.912297 ┆ 21.92104  ┆ NaN       ┆ 1/1       │
# │        ┆            ┆            ┆ 星精选-蚂 ┆   ┆           ┆           ┆           ┆           │
# │        ┆            ┆            ┆ 蚁        ┆   ┆           ┆           ┆           ┆           │
# │ YTD    ┆ 2023-12-29 ┆ 2024-11-22 ┆ 兴证全明  ┆ … ┆ 25.958877 ┆ 22.853567 ┆ NaN       ┆ 1/1       │
# │        ┆            ┆            ┆ 星精选-蚂 ┆   ┆           ┆           ┆           ┆           │
# │        ┆            ┆            ┆ 蚁        ┆   ┆           ┆           ┆           ┆           │
# │ 近9月  ┆ 2024-02-22 ┆ 2024-11-22 ┆ 兴证全明  ┆ … ┆ 25.357836 ┆ 22.588243 ┆ NaN       ┆ 1/1       │
# │        ┆            ┆            ┆ 星精选-蚂 ┆   ┆           ┆           ┆           ┆           │
# │        ┆            ┆            ┆ 蚁        ┆   ┆           ┆           ┆           ┆           │
# │ …      ┆ …          ┆ …          ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ TGDS_2 ┆ 2024-09-30 ┆ 2024-11-22 ┆ 知己私享- ┆ … ┆ -2.433275 ┆ -1.951095 ┆ 57.142857 ┆ 21/36     │
# │        ┆            ┆            ┆ 稳确幸    ┆   ┆           ┆           ┆           ┆           │
# │ 近1月  ┆ 2024-10-22 ┆ 2024-11-22 ┆ 知己私享- ┆ … ┆ -4.363493 ┆ -4.049633 ┆ 11.111111 ┆ 5/37      │
# │        ┆            ┆            ┆ 稳确幸    ┆   ┆           ┆           ┆           ┆           │
# │ MTD    ┆ 2024-10-31 ┆ 2024-11-22 ┆ 知己私享- ┆ … ┆ -3.690076 ┆ -3.227203 ┆ 5.555556  ┆ 3/37      │
# │        ┆            ┆            ┆ 稳确幸    ┆   ┆           ┆           ┆           ┆           │
# │ 近1周  ┆ 2024-11-15 ┆ 2024-11-22 ┆ 知己私享- ┆ … ┆ -23.61522 ┆ -29.93581 ┆ 33.333333 ┆ 13/37     │
# │        ┆            ┆            ┆ 稳确幸    ┆   ┆ 1         ┆ 2         ┆           ┆           │
# │ 近1日  ┆ 2024-11-21 ┆ 2024-11-22 ┆ 知己私享- ┆ … ┆ -34.37250 ┆ -42.34571 ┆ 83.333333 ┆ 31/37     │
# │        ┆            ┆            ┆ 稳确幸    ┆   ┆ 8         ┆ 1         ┆           ┆           │
# └────────┴────────────┴────────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
from quant_utils.db_conn import JJTG_URI
import polars as pl
import quant_utils.data_moudle as dm
def get_fund_performance_inner(
    end_date: str
):
    query_sql = f"""
    SELECT
    TICKER_SYMBOL,
    START_DATE,
    END_DATE,
    CUM_RETURN,
    ANNUAL_RETURN,
    VOLATILITY,
    ANNUAL_VOLATILITY,
    SHARP_RATIO,
    SHARP_RATIO_ANNUAL,
    MAXDD,
    CALMAR_RATIO_ANNUAL,
    MAXDD_DATE,
    MAXDD_RECOVER
    FROM
    fund_performance_inner
    WHERE
    END_DATE = '{end_date}'
    """
    return pl.read_database_uri(query_sql, JJTG_URI).lazy()

trade_dts = dm.get_trade_cal("20241122", "20241126")
for dt in trade_dts:
    get_fund_performance_inner(dt).sink_parquet(f"F:/data_parquet/fund_performance_inner/{dt}.parquet")

# %%
import polars as pl
df1 = pl.DataFrame({"a": [1], "b": [3]})
df2 = pl.DataFrame({"a": [2], "b": [4]})
df3 = pl.DataFrame({"a": [], "b": []})

# %%
df3
# Out:
# shape: (0, 2)
# ┌──────┬──────┐
# │ a    ┆ b    │
# │ ---  ┆ ---  │
# │ null ┆ null │
# ╞══════╪══════╡
# └──────┴──────┘

# %%
import polars as pl
from quant_utils.constant import DB_CONFIG

query_sql = """
WITH a AS (
  SELECT
    REPORT_DATE,
  CASE
      a.IF_TRADING_DAY 
      WHEN 1 THEN
      TRADE_DT ELSE PREV_TRADE_DATE 
    END AS TRADE_DT 
  FROM
    md_tradingdaynew a
    JOIN md_report_date_calender b ON a.TRADE_DT = b.REPORT_DATE 
  WHERE
    1 = 1 
    AND MONTH(REPORT_DATE) = 12 
    AND SECU_MARKET = 83 UNION
  SELECT
    '2024-11-26' AS REPORT_DATE,
'2024-11-26' AS TRADE_DT) SELECT
c.ticker_symbol,
YEAR(c.end_date) AS YEAR,
c.RETURN_RATE_YTD 
FROM
  a
  JOIN fund_type_own b ON a.REPORT_DATE = b.REPORT_DATE
  JOIN fund_nav_gr c ON c.end_date = a.trade_dt 
  AND c.ticker_symbol = b.ticker_symbol 
WHERE
  1 = 1 
  AND b.level_1 = '主动权益' UNION
SELECT
  c.ticker_symbol,
  YEAR(c.end_date) AS YEAR,
  c.RETURN_RATE_YTD 
FROM
  fund_type_own b
  JOIN fund_nav_gr c ON c.end_date = '20241126' 
  AND c.ticker_symbol = b.ticker_symbol 
WHERE
  1 = 1 
  AND b.level_1 = '主动权益' 
  AND b.report_date = '20240930'
"""
def crate_database_uri(database_type: str, config: dict) -> str:
    return f"{database_type}://{config['user']}:{config['pwd']}@{config['host']}:{config['port']}/{config['database']}"


JJTF_URI = crate_database_uri("mysql", DB_CONFIG["jjtg"])

# %%
hs300_query = """
WITH a AS (
  SELECT
    REPORT_DATE,
  CASE
      a.IF_TRADING_DAY 
      WHEN 1 THEN
      TRADE_DT ELSE PREV_TRADE_DATE 
    END AS TRADE_DT 
  FROM
    md_tradingdaynew a
    JOIN md_report_date_calender b ON a.TRADE_DT = b.REPORT_DATE 
  WHERE
    1 = 1 
    AND MONTH(REPORT_DATE) = 12 
    AND SECU_MARKET = 83 UNION
  SELECT
    '2024-11-26' AS REPORT_DATE,
'2024-11-26' AS TRADE_DT) SELECT
YEAR(a.TRADE_DT) AS YEAR,
100*(b.ClosePrice / lag(b.ClosePrice) over (ORDER BY a.TRADE_DT) - 1) AS 'hs300' 
FROM
  a
  JOIN jy_indexquote b ON b.TradingDay = a.TRADE_DT 
  AND a.TRADE_DT <= '20241126' 
  AND b.SecuCode = '000300'
"""

# %%
df = pl.read_database_uri(query_sql, JJTF_URI)
hs300 = pl.read_database_uri(hs300_query, JJTF_URI)

# %%
temp = (
    df.join(hs300, on="YEAR", how="left")
    .with_columns(
        if_win=pl.when(pl.col("RETURN_RATE_YTD") > pl.col("hs300")).then(1).otherwise(0)
    )
)

# %%
temp.group_by("YEAR").agg(
    win_rate=pl.col("if_win").sum() / pl.col("if_win").count()
).sort("YEAR").to_pandas().to_excel("f:/test.xlsx")

# %%
df.group_by("YEAR").agg(
    mean=pl.col("RETURN_RATE_YTD").mean(),
    min=pl.col("RETURN_RATE_YTD").min(),
    percent25=pl.col("RETURN_RATE_YTD").quantile(0.25),
    median=pl.col("RETURN_RATE_YTD").median(),
    percent75=pl.col("RETURN_RATE_YTD").quantile(0.75),
    max=pl.col("RETURN_RATE_YTD").max(),
).sort("YEAR")
# Out:
# shape: (18, 7)
# ┌──────┬────────────┬──────────┬───────────┬──────────┬───────────┬──────────┐
# │ YEAR ┆ mean       ┆ min      ┆ percent25 ┆ median   ┆ percent75 ┆ max      │
# │ ---  ┆ ---        ┆ ---      ┆ ---       ┆ ---      ┆ ---       ┆ ---      │
# │ i64  ┆ f64        ┆ f64      ┆ f64       ┆ f64      ┆ f64       ┆ f64      │
# ╞══════╪════════════╪══════════╪═══════════╪══════════╪═══════════╪══════════╡
# │ 2007 ┆ 105.466149 ┆ 1.2      ┆ 91.9608   ┆ 112.8785 ┆ 129.2366  ┆ 226.2829 │
# │ 2008 ┆ -44.419087 ┆ -66.416  ┆ -53.4285  ┆ -48.4837 ┆ -43.7008  ┆ 6.4938   │
# │ 2009 ┆ 56.501016  ┆ -16.6    ┆ 43.1599   ┆ 61.9221  ┆ 74.3219   ┆ 116.1939 │
# │ 2010 ┆ 4.180169   ┆ -24.0399 ┆ -2.8      ┆ 3.7393   ┆ 10.3231   ┆ 37.7664  │
# │ 2011 ┆ -21.878733 ┆ -50.773  ┆ -26.3     ┆ -22.5281 ┆ -17.9998  ┆ 5.3283   │
# │ …    ┆ …          ┆ …        ┆ …         ┆ …        ┆ …         ┆ …        │
# │ 2020 ┆ 46.597458  ┆ -11.657  ┆ 24.7234   ┆ 46.5848  ┆ 66.1811   ┆ 166.565  │
# │ 2021 ┆ 7.385901   ┆ -32.4985 ┆ -2.8997   ┆ 3.0096   ┆ 15.7362   ┆ 119.4234 │
# │ 2022 ┆ -17.613985 ┆ -50.0748 ┆ -25.0596  ┆ -18.8806 ┆ -11.2489  ┆ 48.5612  │
# │ 2023 ┆ -11.833022 ┆ -46.5001 ┆ -18.3075  ┆ -12.2753 ┆ -5.3635   ┆ 61.0878  │
# │ 2024 ┆ 2.368563   ┆ -37.9426 ┆ -4.179    ┆ 2.4665   ┆ 8.7013    ┆ 74.4251  │
# └──────┴────────────┴──────────┴───────────┴──────────┴───────────┴──────────┘

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('TkAgg')
# df = df.filter(pl.col("YEAR")>=2014)
plt.rcParams['font.sans-serif']=['SimHei']  # 用于显示中文
plt.rcParams['axes.unicode_minus'] = False  # 用于显示中文
sns.boxenplot(x="YEAR", y="RETURN_RATE_YTD", data=df, orient="v")
plt.xlabel("年份")
plt.ylabel("收益率")
plt.show()

# %%
(
    pl
    .scan_parquet("F:/data_parquet/fund_performance_inner/*.parquet")
    .group_by("TICKER_SYMBOL")
    .agg(
        FUND_PERF_START_DATE=pl.col("END_DATE").min(),
        FUND_PERF_END_DATE=pl.col("END_DATE").max()
    )
).collect()
# Out:
# shape: (24_899, 3)
# ┌───────────────┬──────────────────────┬────────────────────┐
# │ TICKER_SYMBOL ┆ FUND_PERF_START_DATE ┆ FUND_PERF_END_DATE │
# │ ---           ┆ ---                  ┆ ---                │
# │ str           ┆ date                 ┆ date               │
# ╞═══════════════╪══════════════════════╪════════════════════╡
# │ 014377        ┆ 2023-06-30           ┆ 2024-11-26         │
# │ 018495        ┆ 2023-06-30           ┆ 2024-11-26         │
# │ 160814        ┆ 2023-06-30           ┆ 2024-05-22         │
# │ 011733        ┆ 2023-06-30           ┆ 2024-11-26         │
# │ 003752        ┆ 2023-06-30           ┆ 2024-11-26         │
# │ …             ┆ …                    ┆ …                  │
# │ 009159        ┆ 2023-06-30           ┆ 2024-11-25         │
# │ 217203        ┆ 2023-06-30           ┆ 2024-11-26         │
# │ 010593        ┆ 2023-06-30           ┆ 2024-11-26         │
# │ 017517        ┆ 2023-06-30           ┆ 2024-11-26         │
# │ 560260        ┆ 2023-09-15           ┆ 2024-11-26         │
# └───────────────┴──────────────────────┴────────────────────┘

# %%
from sqlalchemy import create_engine
from quant_utils.db_conn import PG_DATA_URI, JJTG_URI
from sqlalchemy import inspect, Table,  MetaData
import polars as pl
import os 
from dateutil.parser import parse
metadata = MetaData()
table = Table("chinamutualfundnav", metadata, autoload_with=create_engine(JJTG_URI))
def get_db_table_unque_index(table_name: str, uri: str)-> list[list[str]]:
    # 创建数据库引擎
    engine = create_engine(uri)
    # 创建元数据对象
    inspector = inspect(engine)
    # 获取指定表的索引列表
    indexes = inspector.get_indexes(table_name)
    return [index["column_names"] for index in indexes if index['unique'] is True]

# %%
table.unique_params()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 table.unique_params()
#
# File d:\miniforge3\envs\my312\Lib\site-packages\sqlalchemy\sql\base.py:191, in Immutable.unique_params(self, *optionaldict, **kwargs)
#     190 def unique_params(self, *optionaldict, **kwargs):
# --> 191     raise NotImplementedError("Immutable objects do not support copying")
#
# NotImplementedError: Immutable objects do not support copying

# %%
get_db_table_unque_index("chinamutualfundnav", JJTG_URI)
# Out:
# [['F_INFO_WINDCODE', 'PRICE_DATE']]

# %%
file_root_path = "F:/data_parquet/fund_performance_inner/"
for file_name in os.listdir(file_root_path):
    if file_name.endswith(".parquet"):
        file_path = os.path.join(file_root_path, file_name)
        df = pl.read_parquet(file_path)
        df.write_parquet(
            "d:/test",
            partition_by = ['END_DATE']
        )
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
(
    pl.scan_parquet("F:/data_parquet/fund_performance_inner")
    .filter(pl.col("END_DATE") == parse("20241129"))
).collect()
# Out:
# shape: (681_772, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ TICKER_SY ┆ START_DAT ┆ END_DATE  ┆ CUM_RETUR ┆ … ┆ MAXDD     ┆ CALMAR_RA ┆ MAXDD_DAT ┆ MAXDD_RE │
# │ MBOL      ┆ E         ┆ ---       ┆ N         ┆   ┆ ---       ┆ TIO_ANNUA ┆ E         ┆ COVER    │
# │ ---       ┆ ---       ┆ date      ┆ ---       ┆   ┆ f64       ┆ L         ┆ ---       ┆ ---      │
# │ str       ┆ date      ┆           ┆ f64       ┆   ┆           ┆ ---       ┆ date      ┆ i64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 000001    ┆ 2019-11-2 ┆ 2024-11-2 ┆ -12.06933 ┆ … ┆ 55.096543 ┆ -0.046094 ┆ 2024-02-0 ┆ 99999    │
# │           ┆ 9         ┆ 9         ┆ 9         ┆   ┆           ┆           ┆ 5         ┆          │
# │ 000001    ┆ 2020-11-2 ┆ 2024-11-2 ┆ -35.38002 ┆ … ┆ 55.096543 ┆ -0.187575 ┆ 2024-02-0 ┆ 99999    │
# │           ┆ 7         ┆ 9         ┆ 6         ┆   ┆           ┆           ┆ 5         ┆          │
# │ 000001    ┆ 2021-09-0 ┆ 2024-11-2 ┆ -28.37913 ┆ … ┆ 47.142019 ┆ -0.207918 ┆ 2024-02-0 ┆ 99999    │
# │           ┆ 3         ┆ 9         ┆ 2         ┆   ┆           ┆           ┆ 5         ┆          │
# │ 000001    ┆ 2021-10-1 ┆ 2024-11-2 ┆ -30.81174 ┆ … ┆ 47.142019 ┆ -0.236173 ┆ 2024-02-0 ┆ 99999    │
# │           ┆ 5         ┆ 9         ┆ 4         ┆   ┆           ┆           ┆ 5         ┆          │
# │ 000001    ┆ 2021-11-2 ┆ 2024-11-2 ┆ -31.51499 ┆ … ┆ 47.142019 ┆ -0.251255 ┆ 2024-02-0 ┆ 99999    │
# │           ┆ 9         ┆ 9         ┆ 4         ┆   ┆           ┆           ┆ 5         ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 970214    ┆ 2024-11-0 ┆ 2024-11-2 ┆ 0.773571  ┆ … ┆ 0.027216  ┆ 419.78469 ┆ 2024-11-1 ┆ 1        │
# │           ┆ 1         ┆ 9         ┆           ┆   ┆           ┆ 1         ┆ 8         ┆          │
# │ 970214    ┆ 2024-11-0 ┆ 2024-11-2 ┆ 0.572207  ┆ … ┆ 0.027216  ┆ 425.64791 ┆ 2024-11-1 ┆ 1        │
# │           ┆ 8         ┆ 9         ┆           ┆   ┆           ┆ 9         ┆ 8         ┆          │
# │ 970214    ┆ 2024-11-1 ┆ 2024-11-2 ┆ 0.453597  ┆ … ┆ 0.027216  ┆ 542.26548 ┆ 2024-11-1 ┆ 1        │
# │           ┆ 5         ┆ 9         ┆           ┆   ┆           ┆ 7         ┆ 8         ┆          │
# │ 970214    ┆ 2024-11-2 ┆ 2024-11-2 ┆ 0.289829  ┆ … ┆ 0.0       ┆ null      ┆ null      ┆ 99999    │
# │           ┆ 2         ┆ 9         ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 970214    ┆ 2024-11-2 ┆ 2024-11-2 ┆ 0.081345  ┆ … ┆ 0.0       ┆ null      ┆ null      ┆ 99999    │
# │           ┆ 8         ┆ 9         ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
from quant_utils.db_conn import JJTG_URI
import polars as pl 
query_sql = """
SELECT
  TRADE_DT as END_DATE,
  TICKER_SYMBOL,
  `LEVEL`,
  F_AVGRETURN_DAY,
  F_AVGRETURN_WEEK,
  F_AVGRETURN_MONTH,
  F_AVGRETURN_THISYEAR,
  F_MAXDOWNSIDE_WEEK,
  F_MAXDOWNSIDE_MONTH,
  F_MAXDOWNSIDE_THISYEAR
FROM
  fund_performance_rank
WHERE
  1 = 1 
  AND TRADE_DT = '20241202'
"""
df = pl.read_database_uri(query_sql, JJTG_URI)

# %%
df_ = df.unpivot(
    index=["END_DATE", "TICKER_SYMBOL", "LEVEL"]
).with_columns(
    pl.col("variable").str.split("_").name.keep()
).with_columns(
    pl.col("variable").list.get(1).alias("INDICATOR"),
    pl.col("variable").list.get(2).alias("DATE_NAME"),
).with_columns(
    pl.col("DATE_NAME").replace_strict({"DAY": "近1日", "WEEK": "近1周", "MONTH": "近1月", "THISYEAR": "YTD"}),
    pl.col("INDICATOR").replace_strict({"AVGRETURN": "CUM_RETURN", "MAXDOWNSIDE": "MAXDD"})
)

# %%
df_.pivot(
    index=["END_DATE", "TICKER_SYMBOL", "LEVEL", "DATE_NAME"],
    on="INDICATOR",
    values="value"
)
# Out:
# shape: (238_788, 6)
# ┌────────────┬───────────────┬─────────┬───────────┬────────────┬──────────┐
# │ END_DATE   ┆ TICKER_SYMBOL ┆ LEVEL   ┆ DATE_NAME ┆ CUM_RETURN ┆ MAXDD    │
# │ ---        ┆ ---           ┆ ---     ┆ ---       ┆ ---        ┆ ---      │
# │ date       ┆ str           ┆ str     ┆ str       ┆ str        ┆ str      │
# ╞════════════╪═══════════════╪═════════╪═══════════╪════════════╪══════════╡
# │ 2024-12-02 ┆ 000001        ┆ LEVEL_1 ┆ 近1日     ┆ 5067/7655  ┆ null     │
# │ 2024-12-02 ┆ 000001        ┆ LEVEL_2 ┆ 近1日     ┆ 4612/6991  ┆ null     │
# │ 2024-12-02 ┆ 000001        ┆ LEVEL_3 ┆ 近1日     ┆ 3071/4845  ┆ null     │
# │ 2024-12-02 ┆ 000003        ┆ LEVEL_1 ┆ 近1日     ┆ 48/3192    ┆ null     │
# │ 2024-12-02 ┆ 000003        ┆ LEVEL_2 ┆ 近1日     ┆ 35/235     ┆ null     │
# │ …          ┆ …             ┆ …       ┆ …         ┆ …          ┆ …        │
# │ 2024-12-02 ┆ 970213        ┆ LEVEL_2 ┆ YTD       ┆ 92/184     ┆ 85/184   │
# │ 2024-12-02 ┆ 970213        ┆ LEVEL_3 ┆ YTD       ┆ 46/93      ┆ 48/93    │
# │ 2024-12-02 ┆ 970214        ┆ LEVEL_1 ┆ YTD       ┆ 2061/3016  ┆ 216/3016 │
# │ 2024-12-02 ┆ 970214        ┆ LEVEL_2 ┆ YTD       ┆ 109/184    ┆ 95/184   │
# │ 2024-12-02 ┆ 970214        ┆ LEVEL_3 ┆ YTD       ┆ 61/93      ┆ 53/93    │
# └────────────┴───────────────┴─────────┴───────────┴────────────┴──────────┘
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import glob
from quant_utils.db_conn import PG_LOCAL_URI, JJTG_URI
import polars as pl
from quant_utils.utils import display_time
import numpy as np
from quant_utils.db_conn import DB_CONN_PG_LOCAL, DB_CONN_JJTG_DATA
parquet_path = "F:/data_parquet/fund_performance_rank_pct/"
file_list = glob.glob(f"{parquet_path}*.parquet")
@display_time()
def test(file):
    print("=="*20)
    df = pl.read_parquet(file)
    print(file)
    df = df.with_columns(
                pl.when(pl.col(pl.Float64) > 10**8)
                    .then(np.nan)
                    .otherwise(pl.col(pl.Float64))
                    .name.keep()
        ).with_columns(
            pl.when(pl.col(pl.Float64) < -(10**8))
            .then(np.nan)
            .otherwise(pl.col(pl.Float64))
            .name.keep()
        )
    df.write_database(
        "fund_performance_rank_pct",
        JJTG_URI,
        if_table_exists='append'
    )

for file in file_list:
    test(file)
# Out:
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230630.parquet
# test耗时:8.8428 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230703.parquet
# test耗时:8.7064 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230704.parquet
# test耗时:8.9479 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230705.parquet
# test耗时:8.3578 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230706.parquet
# test耗时:8.5213 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230707.parquet
# test耗时:10.0655 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230710.parquet
# test耗时:12.4849 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230711.parquet
# test耗时:12.2697 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230712.parquet
# test耗时:12.9988 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230713.parquet
# test耗时:12.1361 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230714.parquet
# test耗时:13.4884 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230717.parquet
# test耗时:12.2750 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230718.parquet
# test耗时:11.9546 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230719.parquet
# test耗时:13.3661 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230720.parquet
# test耗时:12.6905 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230721.parquet
# test耗时:9.9795 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230724.parquet
# test耗时:8.3915 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230725.parquet
# test耗时:8.4060 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230726.parquet
# test耗时:8.7352 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230727.parquet
# test耗时:8.4484 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230728.parquet
# test耗时:9.3282 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230731.parquet
# test耗时:8.8630 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230801.parquet
# test耗时:8.8040 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230802.parquet
# test耗时:9.0166 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230803.parquet
# test耗时:8.6515 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230804.parquet
# test耗时:9.0034 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230807.parquet
# test耗时:8.9638 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230808.parquet
# test耗时:8.6307 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230809.parquet
# test耗时:8.9542 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230810.parquet
# test耗时:8.8672 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230811.parquet
# test耗时:9.1369 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230814.parquet
# test耗时:9.1884 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230815.parquet
# test耗时:8.9070 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230816.parquet
# test耗时:8.8739 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230817.parquet
# test耗时:8.9195 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230818.parquet
# test耗时:9.0260 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230821.parquet
# test耗时:8.8395 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230822.parquet
# test耗时:8.8575 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230823.parquet
# test耗时:9.0123 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230824.parquet
# test耗时:8.9900 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230825.parquet
# test耗时:8.9675 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230828.parquet
# test耗时:8.9764 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230829.parquet
# test耗时:8.7115 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230830.parquet
# test耗时:8.8216 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230831.parquet
# test耗时:9.0740 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230901.parquet
# test耗时:9.0407 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230904.parquet
# test耗时:9.0542 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230905.parquet
# test耗时:8.8731 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230906.parquet
# test耗时:8.6846 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230907.parquet
# test耗时:8.9712 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230908.parquet
# test耗时:8.9134 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230911.parquet
# test耗时:8.8768 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230912.parquet
# test耗时:9.3237 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230913.parquet
# test耗时:9.0301 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230914.parquet
# test耗时:9.1833 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230915.parquet
# test耗时:9.1622 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230918.parquet
# test耗时:8.8959 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230919.parquet
# test耗时:9.0893 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230920.parquet
# test耗时:9.0760 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230921.parquet
# test耗时:8.9293 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230922.parquet
# test耗时:9.4254 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230925.parquet
# test耗时:8.8667 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230926.parquet
# test耗时:36.4336 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230927.parquet
# test耗时:34.2964 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20230928.parquet
# test耗时:9.2506 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231009.parquet
# test耗时:8.9552 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231010.parquet
# test耗时:8.6499 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231011.parquet
# test耗时:8.9695 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231012.parquet
# test耗时:8.7687 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231013.parquet
# test耗时:9.2425 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231016.parquet
# test耗时:8.9897 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231017.parquet
# test耗时:8.9229 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231018.parquet
# test耗时:9.1330 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231019.parquet
# test耗时:8.7826 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231020.parquet
# test耗时:9.1127 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231023.parquet
# test耗时:9.2231 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231024.parquet
# test耗时:8.8328 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231025.parquet
# test耗时:8.6701 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231026.parquet
# test耗时:9.0587 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231027.parquet
# test耗时:9.2839 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231030.parquet
# test耗时:9.3444 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231031.parquet
# test耗时:9.3455 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231101.parquet
# test耗时:9.1038 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231102.parquet
# test耗时:9.4902 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231103.parquet
# test耗时:10.4473 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231106.parquet
# test耗时:9.5194 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231107.parquet
# test耗时:9.2300 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231108.parquet
# test耗时:9.4279 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231109.parquet
# test耗时:9.4974 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231110.parquet
# test耗时:9.5072 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231113.parquet
# test耗时:9.3629 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231114.parquet
# test耗时:9.1743 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231115.parquet
# test耗时:9.1984 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231116.parquet
# test耗时:9.7969 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231117.parquet
# test耗时:9.6119 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231120.parquet
# test耗时:9.2801 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231121.parquet
# test耗时:9.4105 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231122.parquet
# test耗时:9.2496 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231123.parquet
# test耗时:9.2909 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231124.parquet
# test耗时:9.4060 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231127.parquet
# test耗时:10.5827 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231128.parquet
# test耗时:9.4299 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231129.parquet
# test耗时:9.2199 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231130.parquet
# test耗时:24.1788 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231201.parquet
# test耗时:49.8065 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231204.parquet
# test耗时:9.3148 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231205.parquet
# test耗时:9.5705 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231206.parquet
# test耗时:9.3679 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231207.parquet
# test耗时:9.3804 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231208.parquet
# test耗时:9.6356 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231211.parquet
# test耗时:10.0686 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231212.parquet
# test耗时:9.1964 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231213.parquet
# test耗时:9.2188 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231214.parquet
# test耗时:9.3858 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231215.parquet
# test耗时:9.3935 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231218.parquet
# test耗时:9.8745 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231219.parquet
# test耗时:10.9476 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231220.parquet
# test耗时:12.0286 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231221.parquet
# test耗时:9.8188 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231222.parquet
# test耗时:9.6056 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231225.parquet
# test耗时:9.2066 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231226.parquet
# test耗时:9.5133 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231227.parquet
# test耗时:9.3422 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231228.parquet
# test耗时:9.9417 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20231229.parquet
# test耗时:10.2672 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240102.parquet
# test耗时:9.6453 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240103.parquet
# test耗时:11.9274 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240104.parquet
# test耗时:10.0412 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240105.parquet
# test耗时:10.1696 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240108.parquet
# test耗时:9.8309 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240109.parquet
# test耗时:9.6685 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240110.parquet
# test耗时:9.7111 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240111.parquet
# test耗时:9.6421 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240112.parquet
# test耗时:10.0419 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240115.parquet
# test耗时:9.8800 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240116.parquet
# test耗时:10.0689 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240117.parquet
# test耗时:9.8809 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240118.parquet
# test耗时:9.5902 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240119.parquet
# test耗时:11.3315 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240122.parquet
# test耗时:26.0241 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240123.parquet
# test耗时:26.4270 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240124.parquet
# test耗时:24.1489 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240125.parquet
# test耗时:9.3092 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240126.parquet
# test耗时:9.9993 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240129.parquet
# test耗时:9.4771 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240130.parquet
# test耗时:9.6859 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240131.parquet
# test耗时:10.3679 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240201.parquet
# test耗时:10.0009 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240202.parquet
# test耗时:10.5232 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240205.parquet
# test耗时:10.5272 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240206.parquet
# test耗时:12.1073 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240207.parquet
# test耗时:11.0132 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240208.parquet
# test耗时:12.2880 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240219.parquet
# test耗时:12.3510 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240220.parquet
# test耗时:11.9070 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240221.parquet
# test耗时:11.9535 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240222.parquet
# test耗时:11.5881 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240223.parquet
# test耗时:11.8075 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240226.parquet
# test耗时:11.9600 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240227.parquet
# test耗时:11.3330 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240228.parquet
# test耗时:11.3435 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240229.parquet
# test耗时:10.7340 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240301.parquet
# test耗时:11.0610 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240304.parquet
# test耗时:11.5490 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240305.parquet
# test耗时:12.4521 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240306.parquet
# test耗时:12.2950 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240307.parquet
# test耗时:11.8910 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240308.parquet
# test耗时:12.2520 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240311.parquet
# test耗时:11.6000 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240312.parquet
# test耗时:11.8940 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240313.parquet
# test耗时:11.4020 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240314.parquet
# test耗时:11.6280 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240315.parquet
# test耗时:12.1265 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240318.parquet
# test耗时:11.0950 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240319.parquet
# test耗时:26.5550 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240320.parquet
# test耗时:49.5547 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240321.parquet
# test耗时:11.2750 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240322.parquet
# test耗时:12.0236 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240325.parquet
# test耗时:11.4615 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240326.parquet
# test耗时:11.3850 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240327.parquet
# test耗时:10.8157 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240328.parquet
# test耗时:9.9431 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240329.parquet
# test耗时:10.3550 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240401.parquet
# test耗时:9.8566 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240402.parquet
# test耗时:10.3953 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240403.parquet
# test耗时:10.2669 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240408.parquet
# test耗时:10.1855 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240409.parquet
# test耗时:10.2509 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240410.parquet
# test耗时:9.7526 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240411.parquet
# test耗时:10.3580 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240412.parquet
# test耗时:9.9673 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240415.parquet
# test耗时:10.3795 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240416.parquet
# test耗时:9.9663 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240417.parquet
# test耗时:9.9810 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240418.parquet
# test耗时:10.4055 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240419.parquet
# test耗时:10.0111 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240422.parquet
# test耗时:10.2756 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240423.parquet
# test耗时:10.1252 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240424.parquet
# test耗时:10.1213 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240425.parquet
# test耗时:10.4360 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240426.parquet
# test耗时:10.0345 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240429.parquet
# test耗时:10.4638 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240430.parquet
# test耗时:10.2268 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240506.parquet
# test耗时:10.3394 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240507.parquet
# test耗时:10.5979 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240508.parquet
# test耗时:10.2155 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240509.parquet
# test耗时:10.3159 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240510.parquet
# test耗时:10.5397 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240513.parquet
# test耗时:10.0544 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240514.parquet
# test耗时:46.2918 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240515.parquet
# test耗时:26.7116 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240516.parquet
# test耗时:10.2706 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240517.parquet
# test耗时:10.2696 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240520.parquet
# test耗时:10.6429 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240521.parquet
# test耗时:10.5982 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240522.parquet
# test耗时:10.7539 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240523.parquet
# test耗时:10.5426 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240524.parquet
# test耗时:10.3644 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240527.parquet
# test耗时:10.3482 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240528.parquet
# test耗时:10.2185 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240529.parquet
# test耗时:10.5600 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240530.parquet
# test耗时:10.1895 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240531.parquet
# test耗时:10.3535 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240603.parquet
# test耗时:10.4490 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240604.parquet
# test耗时:10.2705 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240605.parquet
# test耗时:10.6332 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240606.parquet
# test耗时:10.6666 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240607.parquet
# test耗时:10.4618 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240611.parquet
# test耗时:10.4336 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240612.parquet
# test耗时:10.1444 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240613.parquet
# test耗时:10.4711 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240614.parquet
# test耗时:18.0391 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240617.parquet
# test耗时:17.5839 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240618.parquet
# test耗时:18.2660 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240619.parquet
# test耗时:18.4762 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240620.parquet
# test耗时:10.8030 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240621.parquet
# test耗时:11.0843 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240624.parquet
# test耗时:12.0495 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240625.parquet
# test耗时:10.5462 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240626.parquet
# test耗时:10.4147 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240627.parquet
# test耗时:10.2690 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240628.parquet
# test耗时:10.0626 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240701.parquet
# test耗时:10.2819 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240702.parquet
# test耗时:10.3506 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240703.parquet
# test耗时:10.3989 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240704.parquet
# test耗时:10.6849 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240705.parquet
# test耗时:10.4365 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240708.parquet
# test耗时:10.0714 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240709.parquet
# test耗时:10.0453 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240710.parquet
# test耗时:10.6597 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240711.parquet
# test耗时:10.8629 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240712.parquet
# test耗时:10.6511 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240715.parquet
# test耗时:10.0448 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240716.parquet
# test耗时:10.0736 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240717.parquet
# test耗时:10.6353 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240718.parquet
# test耗时:10.2747 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240719.parquet
# test耗时:10.5495 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240722.parquet
# test耗时:10.3954 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240723.parquet
# test耗时:10.5530 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240724.parquet
# test耗时:10.6010 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240725.parquet
# test耗时:10.3557 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240726.parquet
# test耗时:10.7669 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240729.parquet
# test耗时:10.2038 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240730.parquet
# test耗时:10.8889 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240731.parquet
# test耗时:11.1421 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240801.parquet
# test耗时:11.0994 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240802.parquet
# test耗时:10.9248 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240805.parquet
# test耗时:11.7554 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240806.parquet
# test耗时:37.0435 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240807.parquet
# test耗时:36.7922 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240808.parquet
# test耗时:11.2053 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240809.parquet
# test耗时:10.7535 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240812.parquet
# test耗时:10.6360 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240813.parquet
# test耗时:10.4247 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240814.parquet
# test耗时:10.7674 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240815.parquet
# test耗时:10.4737 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240816.parquet
# test耗时:10.6370 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240819.parquet
# test耗时:10.9467 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240820.parquet
# test耗时:10.6460 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240821.parquet
# test耗时:11.0253 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240822.parquet
# test耗时:10.8224 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240823.parquet
# test耗时:12.8612 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240826.parquet
# test耗时:10.7180 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240827.parquet
# test耗时:10.8518 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240828.parquet
# test耗时:11.9707 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240829.parquet
# test耗时:12.7720 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240830.parquet
# test耗时:13.5730 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240902.parquet
# test耗时:12.4215 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240903.parquet
# test耗时:14.8141 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240904.parquet
# test耗时:14.5035 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240905.parquet
# test耗时:14.1080 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240906.parquet
# test耗时:16.9450 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240909.parquet
# test耗时:13.4108 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240910.parquet
# test耗时:10.7566 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240911.parquet
# test耗时:10.7920 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240912.parquet
# test耗时:73.3777 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240913.parquet
# test耗时:43.4965 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240918.parquet
# test耗时:24.3787 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240919.parquet
# test耗时:37.3464 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240920.parquet
# test耗时:30.4567 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240923.parquet
# test耗时:28.7107 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240924.parquet
# test耗时:26.5268 s
# ========================================
#
# ========================================
# F:/data_parquet/fund_performance_rank_pct\20240925.parquet
# ...
#    4077         raise ValueError(msg)
#    4079     # ensure conversion to pandas uses the pyarrow extension array option
#    4080     # so that we can make use of the sql/db export *without* copying data
# -> 4081     res: int | None = self.to_pandas(
#    4082         use_pyarrow_extension_array=True,
#    4083     ).to_sql(
#    4084         name=unpacked_table_name,
#    4085         schema=db_schema,
#    4086         con=sa_object,
#    4087         if_exists=if_table_exists,
#    4088         index=False,
#    4089         **(engine_options or {}),
#    4090     )
#    4091     return -1 if res is None else res
#    4093 elif isinstance(engine, str):
#
# File d:\miniforge3\envs\my312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File d:\miniforge3\envs\my312\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File d:\miniforge3\envs\my312\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File d:\miniforge3\envs\my312\Lib\site-packages\pandas\io\sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File d:\miniforge3\envs\my312\Lib\site-packages\pandas\io\sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File d:\miniforge3\envs\my312\Lib\site-packages\pandas\io\sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File d:\miniforge3\envs\my312\Lib\site-packages\pandas\io\sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File d:\miniforge3\envs\my312\Lib\site-packages\pandas\io\sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File d:\miniforge3\envs\my312\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File d:\miniforge3\envs\my312\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File d:\miniforge3\envs\my312\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File d:\miniforge3\envs\my312\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File d:\miniforge3\envs\my312\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File d:\miniforge3\envs\my312\Lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File d:\miniforge3\envs\my312\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1934                 break
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#    1943     if self.dialect._has_events:
#
# File d:\miniforge3\envs\my312\Lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:170, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     169 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 170     rowcount = cursor.executemany(statement, parameters)
#     171     if context is not None:
#     172         context._rowcount = rowcount
#
# File d:\miniforge3\envs\my312\Lib\site-packages\MySQLdb\cursors.py:241, in BaseCursor.executemany(self, query, args)
#     239     q_postfix = m.group(3) or ""
#     240     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 241     return self._do_execute_many(
#     242         q_prefix,
#     243         q_values,
#     244         q_postfix,
#     245         args,
#     246         self.max_stmt_length,
#     247         self._get_db().encoding,
#     248     )
#     250 self.rowcount = sum(self.execute(query, arg) for arg in args)
#     251 return self.rowcount
#
# File d:\miniforge3\envs\my312\Lib\site-packages\MySQLdb\cursors.py:270, in BaseCursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     268 v = self._mogrify(values, arg)
#     269 if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 270     rows += self.execute(sql + postfix)
#     271     sql = bytearray(prefix)
#     272 else:
#
# File d:\miniforge3\envs\my312\Lib\site-packages\MySQLdb\cursors.py:179, in BaseCursor.execute(self, query, args)
#     176 mogrified_query = self._mogrify(query, args)
#     178 assert isinstance(mogrified_query, (bytes, bytearray))
# --> 179 res = self._query(mogrified_query)
#     180 return res
#
# File d:\miniforge3\envs\my312\Lib\site-packages\MySQLdb\cursors.py:330, in BaseCursor._query(self, q)
#     328 self.rowcount = None
#     329 self.lastrowid = None
# --> 330 db.query(q)
#     331 self._do_get_result(db)
#     332 self._post_get_result()
#
# File d:\miniforge3\envs\my312\Lib\site-packages\MySQLdb\connections.py:265, in Connection.query(self, query)
#     263 if isinstance(query, bytearray):
#     264     query = bytes(query)
# --> 265 _mysql.connection.query(self, query)
#
# IntegrityError: (MySQLdb.IntegrityError) (1062, "Duplicate entry '2024-11-29-018607-LEVEL_1' for key 'uk'")
# [SQL: INSERT INTO fund_performance_rank_pct (`TICKER_SYMBOL`, `TRADE_DT`, `LEVEL`, `F_AVGRETURN_DAY`, `F_AVGRETURN_WEEK`, `F_AVGRETURN_MONTH`, `F_AVGRETURN_TWOMONTH`, `F_AVGRETURN_THISYEAR`, `F_AVGRETURN_QUARTER`, `F_AVGRETURN_HALFYEAR`, `F_AVGRETURN_YEAR`, `F_AVGRETURN_TWOYEAR`, `F_AVGRETURN_THREEYEAR`, `F_AVGRETURN_FOURYEAR`, `F_AVGRETURN_FIVEYEAR`, `F_STDARDDEV_HALFYEAR`, `F_STDARDDEV_YEAR`, `F_STDARDDEV_TWOYEAR`, `F_STDARDDEV_THREEYEAR`, `F_STDARDDEV_FIVEYEAR`, `F_SHARPRATIO_HALFYEAR`, `F_SHARPRATIO_YEAR`, `F_SHARPRATIO_TWOYEAR`, `F_SHARPRATIO_THREEYEAR`, `F_MAXDOWNSIDE_WEEK`, `F_MAXDOWNSIDE_MONTH`, `F_MAXDOWNSIDE_TWOMONTH`, `F_MAXDOWNSIDE_THISYEAR`, `F_MAXDOWNSIDE_QUARTER`, `F_MAXDOWNSIDE_HALFYEAR`, `F_MAXDOWNSIDE_YEAR`, `F_MAXDOWNSIDE_TWOYEAR`, `F_MAXDOWNSIDE_THREEYEAR`, `F_CALMAR_THISYEAR`, `F_CALMAR_QUARTER`, `F_CALMAR_HALFYEAR`, `F_CALMAR_YEAR`, `F_CALMAR_TWOYEAR`, `F_CALMAR_THREEYEAR`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)]
# [parameters: [('018607', datetime.datetime(2024, 11, 29, 0, 0), 'LEVEL_1', 68.51441241685144, 66.07538802660754, 68.73614190687361, 62.97117516629712, 68.90951276102088, 65.77777777777779, 63.707865168539335, 71.17852975495916, None, None, None, None, 38.651685393258425, 28.238039673278877, None, None, None, 64.73922902494331, 50.94117647058823, None, None, 49.889135254988915, 49.889135254988915, 49.667405764966745, 49.30394431554524, 49.55555555555556, 49.55056179775281, 49.35822637106184, None, None, None, None, None, None, None, None), ('020138', datetime.datetime(2024, 11, 29, 0, 0), 'LEVEL_1', 85.10971786833856, 79.25483577826822, 68.96551724137932, 88.45904193171492, None, 97.59558533701221, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 21.91354017915098, 45.5067920585162, 7.906010645203168, None, 7.226382866903166, None, None, None, None, None, 97.49014454664913, None, None, None, None), ('007480', datetime.datetime(2024, 11, 29, 0, 0), 'LEVEL_2', 57.341907824222936, 92.65175718849841, 98.60365198711062, 90.40511727078892, 97.73499433748584, 87.54098360655738, 94.2889137737962, 98.25174825174825, 97.724039829303, 94.22222222222221, 86.23595505617978, None, 2.3516237402015676, 6.75990675990676, 36.984352773826465, 81.55555555555556, None, 11.235955056179776, 64.01869158878503, 91.31054131054131, 94.22222222222221, 48.13631522896699, 80.45112781954887, 3.9445628997867805, 5.436013590033975, 2.2950819672131146, 1.9036954087346025, 5.244755244755245, 20.056899004267425, 70.66666666666667, 19.931662870159453, 2.86028602860286, 2.2522522522522523, 15.303738317757007, 64.95726495726495, 90.22222222222223), ('010019', datetime.datetime(2024, 11, 29, 0, 0), 'LEVEL_3', 46.20611551528879, 80.35714285714285, 83.46545866364666, 74.55357142857142, 71.31336405529954, 69.88636363636364, 83.17972350230414, 71.39451728247914, 52.40112994350282, 43.542435424354245, 64.28571428571428, None, 30.760368663594466, 29.916567342073897, 15.3954802259887, 2.5830258302583027, None, 83.52534562211981, 63.5280095351609, 45.05649717514124, 38.92988929889299, 83.70535714285714, 47.56511891279728, 27.566964285714285, 52.88018433179723, 26.81818181818182, 55.99078341013824, 49.70202622169249, 39.12429378531073, 15.129151291512915, 69.23963133640552, 57.15909090909091, 83.52534562211981, 68.29558998808103, 48.163841807909606, 37.82287822878229), ('014092', datetime.datetime(2024, 11, 29, 0, 0), 'LEVEL_2', 53.846153846153854, 38.46153846153847, 38.46153846153847, 69.23076923076923, 84.61538461538463, 84.61538461538463, 53.846153846153854, 84.61538461538463, 69.23076923076923, None, None, None, 76.92307692307693, 61.53846153846154, 76.92307692307693, None, None, 53.846153846153854, 76.92307692307693, 61.53846153846154, None, 92.3076923076923, 84.61538461538463, 84.61538461538463, 23.076923076923077, 84.61538461538463, 69.23076923076923, 30.76923076923077, 69.23076923076923, None, 53.846153846153854, 84.61538461538463, 53.846153846153854, 69.23076923076923, 69.23076923076923, None), ('001552', datetime.datetime(2024, 11, 29, 0, 0), 'LEVEL_2', 21.32701421800948, 26.38230647709321, 20.221169036334913, 35.8609794628752, 0.37523452157598497, 14.94435612082671, 9.491525423728813, 1.1516314779270633, 2.2321428571428568, 11.3314447592068, 35.447761194029844, 39.075630252100844, 60.84745762711864, 57.19769673704415, 63.61607142857143, 58.923512747875364, 70.16806722689076, 4.406779661016949, 7.1017274472168905, 5.803571428571428, 13.31444759206799, 40.758293838862556, 92.73301737756714, 59.08372827804107, 21.388367729831145, 58.9825119236884, 31.525423728813557, 25.335892514395393, 33.70535714285714, 23.79603399433428, 3.9399624765478425, 16.534181240063596, 4.745762711864407, 6.142034548944338, 6.473214285714285, 13.031161473087819), ('019418', datetime.datetime(2024, 11, 29, 0, 0), 'LEVEL_1', 70.2728127939793, 46.42528382939552, 30.222361415596623, 36.66768947529917, 27.370129870129873, 40.39860803543182, 38.012262020006 ...
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
from quant_utils.db_conn import DB_CONN_JJTG_DATA
import pandas as pd
import polars as pl

# %%
trade_dts = ["20240405"]
period_end_date_list = []
for date in trade_dts:
        # 特别日期
        if date > "20240329":
            period_end_date_list.append(
                {"DATE_NAME": "TGDS_1", "START_DATE": "20240329", "END_DATE": date}
            )
        if date > "20240930":
            period_end_date_list.append(
                {"DATE_NAME": "TGDS_2", "START_DATE": "20240930", "END_DATE": date}
            )
period_end_date_df = pd.DataFrame(period_end_date_list)

# %%
period_end_date_df
# Out:
#   DATE_NAME START_DATE  END_DATE
# 0    TGDS_1   20240329  20240405

# %%
for i in df["DATE_NAME"].unique():
    print(i)
# Out:
# 近5年
# WTD
# 近10年
# 近1月
# 近2年
# 近1周
# 近3年
# 近7年
# 近1日
# 近6月
# 近9月
# YTD
# 近4年
# 近8年
# 近1年
# 近2月
# 近6年
# MTD
# 近9年
# 近3月
# QTD

# %%
rename_dict
# Out:
# {'WEEK_END_DATE': 'WTD',
#  'MONTH_END_DATE': 'MTD',
#  'YEAR_END_DATE': 'YTD',
#  'QUARTER_END_DATE': 'QTD',
#  'PREV_TRADE_DATE': '近1日',
#  'PREV_1_WEEK': '近1周',
#  'PREV_1_MONTH': '近1月',
#  'PREV_2_MONTH': '近2月',
#  'PREV_3_MONTH': '近3月',
#  'PREV_6_MONTH': '近6月',
#  'PREV_9_MONTH': '近9月',
#  'PREV_1_YEAR': '近1年',
#  'PREV_2_YEAR': '近2年',
#  'PREV_3_YEAR': '近3年',
#  'PREV_4_YEAR': '近4年',
#  'PREV_5_YEAR': '近5年',
#  'PREV_6_YEAR': '近6年',
#  'PREV_7_YEAR': '近7年',
#  'PREV_8_YEAR': '近8年',
#  'PREV_9_YEAR': '近9年',
#  'PREV_10_YEAR': '近10年'}

# %%
from quant_utils.db_conn import DB_CONN_JJTG_DATA

df = DB_CONN_JJTG_DATA.exec_query(
    """SELECT
  * 
FROM
  aindex_eod_prices 
WHERE
  1 = 1 
  AND TICKER_SYMBOL IN ("881001", "000922", "8841431") 
  AND TRADE_DT >= '20240101'"""
)
df = df.pivot_table(index="TRADE_DT", columns="TICKER_SYMBOL", values="S_DQ_AMOUNT")
# Out:
# exec_query耗时:0.0250 s
# ========================================

# %%
df["微盘股成交额占比"] = (df["8841431"]/ df["881001"]) * 100
df["红利成交占比"] = (df["000922"] / df["881001"]) * 100
df["微盘股成交额占比"] = df["微盘股成交额占比"].rolling(5).mean()
df["红利成交占比"] = df["红利成交占比"].rolling(5).mean()
df.to_excel("d:/test.xlsx")
