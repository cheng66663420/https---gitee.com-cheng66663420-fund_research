# %%
import datetime
import math
import os
import struct
import csv
import pandas as pd
import requests

from numba import jit
GlobalSession = requests.session()

from dateutil.parser import parse

import quant_utils.data_moudle as dm
from quant_utils.constant import DB_CONN_LOCAL_MYSQL

def create_table(code):
    query_sql = f"""
        CREATE TABLE IF not exists `{code}` (
        `ID` bigint(20) unsigned NOT NULL AUTO_INCREMENT,
        `code` varchar(20) CHARACTER SET utf8mb4 COLLATE utf8mb4_bin DEFAULT NULL,
        `trade_time` datetime DEFAULT NULL,
        `date` date DEFAULT NULL,
        `tick` varchar(20) COLLATE utf8mb4_bin DEFAULT NULL,
        `open` double(20,6) DEFAULT NULL,
        `high` double(20,6) DEFAULT NULL,
        `low` double(20,6) DEFAULT NULL,
        `close` double(20,6) DEFAULT NULL,
        `turnover` double(20,4) DEFAULT NULL,
        `total_amount` double(20,4) DEFAULT NULL,
        `update_time` datetime DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
        PRIMARY KEY (`ID`),
        UNIQUE KEY `datetime` (`trade_time`) USING BTREE
        ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4 COLLATE=utf8mb4_bin;
    """
    DB_CONN_LOCAL_MYSQL.exec_non_query(query_sql)

# %%
file_path = 'E:/行情/指数1分钟/'
file_list = os.listdir(file_path)
for file in file_list:
    code = file.split(".")
    table_name = code[1] + code[0]
    code_name = f"{code[0]}.{code[1]}"
    # if code[0] == '1':
    #     table_name = f"SZ{code}"
    #     code_name = f"{code}.SZ"

    # elif code[0] == '5':
    #     table_name = f"SH{code}"
    #     code_name = f"{code}.SH"
    print(table_name)
    create_table(table_name)
    df = fast_read(file_path + file)
    print("读取完成")
    df.rename(
        columns={
            "vol": "turnover",
            "amount": "total_amount",
        },
        inplace=True
    )
    df["code"] = code_name
    df["date"] = df.trade_time.apply(lambda s: s[:10])
    df["tick"] = df.trade_time.apply(lambda s: s[11:].replace(":", ""))
    print("开始写入")
    DB_CONN_LOCAL_MYSQL.upsert(df, table=table_name)
    print("写入完成")
    print("=="*40)
# Out:
# SH000001
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000001-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000002
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000002-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000003
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000003-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000004
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000004-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000005
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000005-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000006
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000006-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000007
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000007-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000008
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000008-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000009
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000009-受影响行数为771360行!
# 写入完成
# ==*40
# SH000010
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000010-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000011
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000011-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000012
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000012-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000015
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000015-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000016
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000016-受影响行数为1115040行!
# 写入完成
# ==*40
# SH000017
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000017-受影响行数为1056960行!
# 写入完成
# ==*40
# SH000018
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000018-受影响行数为944640行!
# 写入完成
# ==*40
# SH000019
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000019-受影响行数为941040行!
# 写入完成
# ==*40
# SH000020
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000020-受影响行数为920640行!
# 写入完成
# ==*40
# SH000021
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000021-受影响行数为900000行!
# 写入完成
# ==*40
# SH000022
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000022-受影响行数为889440行!
# 写入完成
# ==*40
# SH000025
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000025-受影响行数为885120行!
# 写入完成
# ==*40
# SH000026
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000026-受影响行数为885120行!
# 写入完成
# ==*40
# SH000027
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000027-受影响行数为885120行!
# 写入完成
# ==*40
# SH000028
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000028-受影响行数为881040行!
# 写入完成
# ==*40
# SH000029
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000029-受影响行数为881040行!
# 写入完成
# ==*40
# SH000030
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000030-受影响行数为881040行!
# 写入完成
# ==*40
# SH000031
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000031-受影响行数为881040行!
# 写入完成
# ==*40
# SH000032
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000032-受影响行数为881040行!
# 写入完成
# ==*40
# SH000033
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000033-受影响行数为881040行!
# 写入完成
# ==*40
# SH000034
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000034-受影响行数为881040行!
# 写入完成
# ==*40
# SH000035
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000035-受影响行数为881040行!
# 写入完成
# ==*40
# SH000036
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000036-受影响行数为881040行!
# 写入完成
# ==*40
# SH000037
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000037-受影响行数为881040行!
# 写入完成
# ==*40
# SH000038
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000038-受影响行数为881040行!
# 写入完成
# ==*40
# SH000039
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000039-受影响行数为881040行!
# 写入完成
# ==*40
# SH000040
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000040-受影响行数为881040行!
# 写入完成
# ==*40
# SH000041
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000041-受影响行数为881040行!
# 写入完成
# ==*40
# SH000042
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000042-受影响行数为868800行!
# 写入完成
# ==*40
# SH000043
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000043-受影响行数为864720行!
# 写入完成
# ==*40
# SH000044
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000044-受影响行数为853200行!
# 写入完成
# ==*40
# SH000045
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000045-受影响行数为853200行!
# 写入完成
# ==*40
# SH000046
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000046-受影响行数为853200行!
# 写入完成
# ==*40
# SH000047
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000047-受影响行数为853200行!
# 写入完成
# ==*40
# SH000048
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000048-受影响行数为847680行!
# 写入完成
# ==*40
# SH000049
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000049-受影响行数为844320行!
# 写入完成
# ==*40
# SH000050
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000050-受影响行数为765360行!
# 写入完成
# ==*40
# SH000051
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000051-受影响行数为743280行!
# 写入完成
# ==*40
# SH000052
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000052-受影响行数为706080行!
# 写入完成
# ==*40
# SH000053
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000053-受影响行数为706080行!
# 写入完成
# ==*40
# SH000054
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000054-受影响行数为823440行!
# 写入完成
# ==*40
# SH000055
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000055-受影响行数为823440行!
# 写入完成
# ==*40
# SH000056
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000056-受影响行数为823440行!
# 写入完成
# ==*40
# SH000057
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000057-受影响行数为823440行!
# 写入完成
# ==*40
# SH000058
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000058-受影响行数为823440行!
# 写入完成
# ==*40
# SH000059
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000059-受影响行数为823440行!
# 写入完成
# ==*40
# SH000060
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000060-受影响行数为823440行!
# 写入完成
# ==*40
# SH000061
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000061-受影响行数为807840行!
# 写入完成
# ==*40
# SH000062
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000062-受影响行数为823440行!
# 写入完成
# ==*40
# SH000063
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000063-受影响行数为818160行!
# 写入完成
# ==*40
# SH000064
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000064-受影响行数为818160行!
# 写入完成
# ==*40
# SH000065
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000065-受影响行数为817200行!
# 写入完成
# ==*40
# SH000066
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000066-受影响行数为804720行!
# 写入完成
# ==*40
# SH000067
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000067-受影响行数为804720行!
# 写入完成
# ==*40
# SH000068
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000068-受影响行数为800160行!
# 写入完成
# ==*40
# SH000069
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000069-受影响行数为800160行!
# 写入完成
# ==*40
# SH000070
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000070-受影响行数为786960行!
# 写入完成
# ==*40
# SH000071
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000071-受影响行数为786960行!
# 写入完成
# ==*40
# SH000072
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000072-受影响行数为786960行!
# 写入完成
# ==*40
# SH000073
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000073-受影响行数为786960行!
# 写入完成
# ==*40
# SH000074
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000074-受影响行数为786960行!
# 写入完成
# ==*40
# SH000075
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000075-受影响行数为786960行!
# 写入完成
# ==*40
# SH000076
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000076-受影响行数为786960行!
# 写入完成
# ==*40
# SH000077
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000077-受影响行数为786960行!
# 写入完成
# ==*40
# SH000078
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000078-受影响行数为786960行!
# 写入完成
# ==*40
# SH000079
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000079-受影响行数为786960行!
# 写入完成
# ==*40
# SH000090
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000090-受影响行数为770640行!
# 写入完成
# ==*40
# SH000091
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000091-受影响行数为751200行!
# 写入完成
# ==*40
# SH000092
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000092-受影响行数为745680行!
# 写入完成
# ==*40
# SH000093
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000093-受影响行数为743280行!
# 写入完成
# ==*40
# SH000094
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000094-受影响行数为745680行!
# 写入完成
# ==*40
# SH000095
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000095-受影响行数为745680行!
# 写入完成
# ==*40
# SH000096
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000096-受影响行数为745680行!
# 写入完成
# ==*40
# SH000097
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000097-受影响行数为743280行!
# 写入完成
# ==*40
# SH000098
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000098-受影响行数为736800行!
# 写入完成
# ==*40
# SH000099
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000099-受影响行数为736800行!
# 写入完成
# ==*40
# SH000100
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000100-受影响行数为736800行!
# 写入完成
# ==*40
# SH000101
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000101-受影响行数为635040行!
# 写入完成
# ==*40
# SH000102
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000102-受影响行数为740160行!
# 写入完成
# ==*40
# SH000103
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000103-受影响行数为740160行!
# 写入完成
# ==*40
# SH000104
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000104-受影响行数为740160行!
# 写入完成
# ==*40
# SH000105
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000105-受影响行数为740160行!
# 写入完成
# ==*40
# SH000106
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000106-受影响行数为740160行!
# 写入完成
# ==*40
# SH000107
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000107-受影响行数为740160行!
# 写入完成
# ==*40
# SH000108
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000108-受影响行数为740160行!
# 写入完成
# ==*40
# SH000109
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000109-受影响行数为740160行!
# 写入完成
# ==*40
# SH000110
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000110-受影响行数为740160行!
# 写入完成
# ==*40
# SH000111
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000111-受影响行数为740160行!
# 写入完成
# ==*40
# SH000112
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000112-受影响行数为740160行!
# 写入完成
# ==*40
# SH000113
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000113-受影响行数为740160行!
# 写入完成
# ==*40
# SH000114
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000114-受影响行数为728160行!
# 写入完成
# ==*40
# SH000115
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000115-受影响行数为729600行!
# 写入完成
# ==*40
# SH000116
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000116-受影响行数为640800行!
# 写入完成
# ==*40
# SH000117
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000117-受影响行数为719760行!
# 写入完成
# ==*40
# SH000118
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000118-受影响行数为719760行!
# 写入完成
# ==*40
# SH000119
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000119-受影响行数为719760行!
# 写入完成
# ==*40
# SH000120
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000120-受影响行数为719760行!
# 写入完成
# ==*40
# SH000121
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000121-受影响行数为719760行!
# 写入完成
# ==*40
# SH000122
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000122-受影响行数为719760行!
# 写入完成
# ==*40
# SH000123
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000123-受影响行数为642480行!
# 写入完成
# ==*40
# SH000125
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000125-受影响行数为642480行!
# 写入完成
# ==*40
# SH000126
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000126-受影响行数为710640行!
# 写入完成
# ==*40
# SH000128
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000128-受影响行数为706080行!
# 写入完成
# ==*40
# SH000129
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000129-受影响行数为706080行!
# 写入完成
# ==*40
# SH000130
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000130-受影响行数为706080行!
# 写入完成
# ==*40
# SH000131
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000131-受影响行数为701520行!
# 写入完成
# ==*40
# SH000132
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000132-受影响行数为690240行!
# 写入完成
# ==*40
# SH000133
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000133-受影响行数为690240行!
# 写入完成
# ==*40
# SH000134
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000134-受影响行数为684240行!
# 写入完成
# ==*40
# SH000135
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000135-受影响行数为672720行!
# 写入完成
# ==*40
# SH000136
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000136-受影响行数为672720行!
# 写入完成
# ==*40
# SH000137
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000137-受影响行数为672720行!
# 写入完成
# ==*40
# SH000138
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000138-受影响行数为672720行!
# 写入完成
# ==*40
# SH000139
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000139-受影响行数为666240行!
# 写入完成
# ==*40
# SH000141
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000141-受影响行数为642480行!
# 写入完成
# ==*40
# SH000142
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000142-受影响行数为642480行!
# 写入完成
# ==*40
# SH000145
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000145-受影响行数为684240行!
# 写入完成
# ==*40
# SH000146
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000146-受影响行数为684240行!
# 写入完成
# ==*40
# SH000147
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000147-受影响行数为684240行!
# 写入完成
# ==*40
# SH000148
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000148-受影响行数为684240行!
# 写入完成
# ==*40
# SH000149
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000149-受影响行数为675360行!
# 写入完成
# ==*40
# SH000150
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000150-受影响行数为675360行!
# 写入完成
# ==*40
# SH000151
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000151-受影响行数为675360行!
# 写入完成
# ==*40
# SH000152
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000152-受影响行数为675360行!
# 写入完成
# ==*40
# SH000153
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000153-受影响行数为675360行!
# 写入完成
# ==*40
# SH000155
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000155-受影响行数为675360行!
# 写入完成
# ==*40
# SH000158
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000158-受影响行数为664080行!
# 写入完成
# ==*40
# SH000159
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000159-受影响行数为540480行!
# 写入完成
# ==*40
# SH000160
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000160-受影响行数为505200行!
# 写入完成
# ==*40
# SH000161
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000161-受影响行数为485040行!
# 写入完成
# ==*40
# SH000162
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000162-受影响行数为485040行!
# 写入完成
# ==*40
# SH000300
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000300-受影响行数为1100400行!
# 写入完成
# ==*40
# SH000682
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000682-受影响行数为145680行!
# 写入完成
# ==*40
# SH000683
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000683-受影响行数为104400行!
# 写入完成
# ==*40
# SH000685
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000685-受影响行数为98640行!
# 写入完成
# ==*40
# SH000687
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000687-受影响行数为87840行!
# 写入完成
# ==*40
# SH000688
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000688-受影响行数为208080行!
# 写入完成
# ==*40
# SH000689
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000689-受影响行数为87840行!
# 写入完成
# ==*40
# SH000690
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000690-受影响行数为75120行!
# 写入完成
# ==*40
# SH000692
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000692-受影响行数为51120行!
# 写入完成
# ==*40
# SH000693
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000693-受影响行数为51120行!
# 写入完成
# ==*40
# SH000695
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000695-受影响行数为51120行!
# 写入完成
# ==*40
# SH000697
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000697-受影响行数为51120行!
# 写入完成
# ==*40
# SH000698
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000698-受影响行数为33120行!
# 写入完成
# ==*40
# SH000802
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000802-受影响行数为716160行!
# 写入完成
# ==*40
# SH000814
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000814-受影响行数为691920行!
# 写入完成
# ==*40
# SH000819
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000819-受影响行数为687600行!
# 写入完成
# ==*40
# SH000823
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000823-受影响行数为615360行!
# 写入完成
# ==*40
# SH000827
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000827-受影响行数为664080行!
# 写入完成
# ==*40
# SH000847
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000847-受影响行数为577680行!
# 写入完成
# ==*40
# SH000849
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000849-受影响行数为570000行!
# 写入完成
# ==*40
# SH000851
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000851-受影响行数为552720行!
# 写入完成
# ==*40
# SH000852
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000852-受影响行数为545520行!
# 写入完成
# ==*40
# SH000853
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000853-受影响行数为507840行!
# 写入完成
# ==*40
# SH000854
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000854-受影响行数为399120行!
# 写入完成
# ==*40
# SH000855
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000855-受影响行数为541440行!
# 写入完成
# ==*40
# SH000856
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000856-受影响行数为399120行!
# 写入完成
# ==*40
# SH000857
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000857-受影响行数为399120行!
# 写入完成
# ==*40
# SH000858
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000858-受影响行数为399120行!
# 写入完成
# ==*40
# SH000891
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000891-受影响行数为398880行!
# 写入完成
# ==*40
# SH000901
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000901-受影响行数为809520行!
# 写入完成
# ==*40
# SH000903
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000903-受影响行数为1035120行!
# 写入完成
# ==*40
# SH000905
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000905-受影响行数为997440行!
# 写入完成
# ==*40
# SH000906
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000906-受影响行数为997440行!
# 写入完成
# ==*40
# SH000913
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000913-受影响行数为971040行!
# 写入完成
# ==*40
# SH000914
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000914-受影响行数为971040行!
# 写入完成
# ==*40
# SH000928
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000928-受影响行数为853200行!
# 写入完成
# ==*40
# SH000932
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000932-受影响行数为853200行!
# 写入完成
# ==*40
# SH000933
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000933-受影响行数为853200行!
# 写入完成
# ==*40
# SH000934
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000934-受影响行数为853200行!
# 写入完成
# ==*40
# SH000935
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000935-受影响行数为853200行!
# 写入完成
# ==*40
# SH000974
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000974-受影响行数为615360行!
# 写入完成
# ==*40
# SH000982
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000982-受影响行数为740160行!
# 写入完成
# ==*40
# SH000985
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000985-受影响行数为726960行!
# 写入完成
# ==*40
# SH000986
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000986-受影响行数为731520行!
# 写入完成
# ==*40
# SH000987
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000987-受影响行数为731520行!
# 写入完成
# ==*40
# SH000989
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000989-受影响行数为731520行!
# 写入完成
# ==*40
# SH000991
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000991-受影响行数为731520行!
# 写入完成
# ==*40
# SH000992
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000992-受影响行数为731520行!
# 写入完成
# ==*40
# SH000993
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SH000993-受影响行数为731520行!
# 写入完成
# ==*40
# SZ399001
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399001-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399002
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399002-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399003
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399003-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399004
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399004-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399005
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399005-受影响行数为912480行!
# 写入完成
# ==*40
# SZ399006
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399006-受影响行数为799680行!
# 写入完成
# ==*40
# SZ399007
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399007-受影响行数为833520行!
# 写入完成
# ==*40
# SZ399008
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399008-受影响行数为811440行!
# 写入完成
# ==*40
# SZ399009
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399009-受影响行数为726240行!
# 写入完成
# ==*40
# SZ399010
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399010-受影响行数为726240行!
# 写入完成
# ==*40
# SZ399011
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399011-受影响行数为726240行!
# 写入完成
# ==*40
# SZ399012
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399012-受影响行数为648240行!
# 写入完成
# ==*40
# SZ399013
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399013-受影响行数为567840行!
# 写入完成
# ==*40
# SZ399015
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399015-受影响行数为520320行!
# 写入完成
# ==*40
# SZ399016
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399016-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399017
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399017-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399018
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399018-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399019
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399019-受影响行数为15120行!
# 写入完成
# ==*40
# SZ399020
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399020-受影响行数为15120行!
# 写入完成
# ==*40
# SZ399030
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399030-受影响行数为138720行!
# 写入完成
# ==*40
# SZ399050
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399050-受影响行数为323280行!
# 写入完成
# ==*40
# SZ399060
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399060-受影响行数为138720行!
# 写入完成
# ==*40
# SZ399088
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399088-受影响行数为233280行!
# 写入完成
# ==*40
# SZ399100
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399100-受影响行数为1051200行!
# 写入完成
# ==*40
# SZ399101
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399101-受影响行数为1062240行!
# 写入完成
# ==*40
# SZ399102
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399102-受影响行数为786480行!
# 写入完成
# ==*40
# SZ399103
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399103-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399106
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399106-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399107
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399107-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399108
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399108-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399231
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399231-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399232
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399232-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399233
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399233-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399234
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399234-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399235
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399235-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399236
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399236-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399237
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399237-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399238
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399238-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399239
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399239-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399240
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399240-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399241
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399241-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399242
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399242-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399243
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399243-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399244
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399244-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399248
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399248-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399249
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399249-受影响行数为639840行!
# 写入完成
# ==*40
# SZ399258
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399258-受影响行数为30480行!
# 写入完成
# ==*40
# SZ399259
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399259-受影响行数为30480行!
# 写入完成
# ==*40
# SZ399260
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399260-受影响行数为30480行!
# 写入完成
# ==*40
# SZ399261
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399261-受影响行数为30480行!
# 写入完成
# ==*40
# SZ399269
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399269-受影响行数为180000行!
# 写入完成
# ==*40
# SZ399274
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399274-受影响行数为108480行!
# 写入完成
# ==*40
# SZ399275
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399275-受影响行数为193200行!
# 写入完成
# ==*40
# SZ399276
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399276-受影响行数为193200行!
# 写入完成
# ==*40
# SZ399277
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399277-受影响行数为220320行!
# 写入完成
# ==*40
# SZ399278
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399278-受影响行数为220320行!
# 写入完成
# ==*40
# SZ399279
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399279-受影响行数为220320行!
# 写入完成
# ==*40
# SZ399280
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399280-受影响行数为220320行!
# 写入完成
# ==*40
# SZ399281
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399281-受影响行数为220320行!
# 写入完成
# ==*40
# SZ399282
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399282-受影响行数为233280行!
# 写入完成
# ==*40
# SZ399283
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399283-受影响行数为233280行!
# 写入完成
# ==*40
# SZ399284
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399284-受影响行数为233280行!
# 写入完成
# ==*40
# SZ399285
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399285-受影响行数为233280行!
# 写入完成
# ==*40
# SZ399286
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399286-受影响行数为241200行!
# 写入完成
# ==*40
# SZ399289
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399289-受影响行数为104160行!
# 写入完成
# ==*40
# SZ399290
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399290-受影响行数为274080行!
# 写入完成
# ==*40
# SZ399291
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399291-受影响行数为249600行!
# 写入完成
# ==*40
# SZ399292
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399292-受影响行数为289200行!
# 写入完成
# ==*40
# SZ399293
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399293-受影响行数为281760行!
# 写入完成
# ==*40
# SZ399294
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399294-受影响行数为274080行!
# 写入完成
# ==*40
# SZ399295
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399295-受影响行数为294960行!
# 写入完成
# ==*40
# SZ399296
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399296-受影响行数为294960行!
# 写入完成
# ==*40
# SZ399298
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399298-受影响行数为548160行!
# 写入完成
# ==*40
# SZ399299
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399299-受影响行数为547440行!
# 写入完成
# ==*40
# SZ399300
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399300-受影响行数为1100400行!
# 写入完成
# ==*40
# SZ399301
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399301-受影响行数为633120行!
# 写入完成
# ==*40
# SZ399302
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399302-受影响行数为633120行!
# 写入完成
# ==*40
# SZ399303
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399303-受影响行数为577920行!
# 写入完成
# ==*40
# SZ399306
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399306-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399307
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399307-受影响行数为551280行!
# 写入完成
# ==*40
# SZ399310
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399310-受影响行数为1075920行!
# 写入完成
# ==*40
# SZ399311
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399311-受影响行数为1109760行!
# 写入完成
# ==*40
# SZ399312
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399312-受影响行数为1109760行!
# 写入完成
# ==*40
# SZ399313
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399313-受影响行数为1109760行!
# 写入完成
# ==*40
# SZ399314
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399314-受影响行数为1109760行!
# 写入完成
# ==*40
# SZ399315
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399315-受影响行数为1109760行!
# 写入完成
# ==*40
# SZ399316
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399316-受影响行数为1109760行!
# 写入完成
# ==*40
# SZ399317
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399317-受影响行数为1109760行!
# 写入完成
# ==*40
# SZ399318
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399318-受影响行数为1103040行!
# 写入完成
# ==*40
# SZ399319
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399319-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399320
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399320-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399321
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399321-受影响行数为1114800行!
# 写入完成
# ==*40
# SZ399322
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399322-受影响行数为1060560行!
# 写入完成
# ==*40
# SZ399324
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399324-受影响行数为1053600行!
# 写入完成
# ==*40
# SZ399326
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399326-受影响行数为1053600行!
# 写入完成
# ==*40
# SZ399328
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399328-受影响行数为1053600行!
# 写入完成
# ==*40
# SZ399330
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399330-受影响行数为1053360行!
# 写入完成
# ==*40
# SZ399333
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399333-受影响行数为999840行!
# 写入完成
# ==*40
# SZ399335
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399335-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399337
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399337-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399339
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399339-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399341
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399341-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399344
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399344-受影响行数为833520行!
# 写入完成
# ==*40
# SZ399346
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399346-受影响行数为833520行!
# 写入完成
# ==*40
# SZ399348
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399348-受影响行数为833520行!
# 写入完成
# ==*40
# SZ399350
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399350-受影响行数为650880行!
# 写入完成
# ==*40
# SZ399351
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399351-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399352
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399352-受影响行数为1109760行!
# 写入完成
# ==*40
# SZ399353
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399353-受影响行数为1107120行!
# 写入完成
# ==*40
# SZ399354
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399354-受影响行数为399360行!
# 写入完成
# ==*40
# SZ399355
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399355-受影响行数为971040行!
# 写入完成
# ==*40
# SZ399356
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399356-受影响行数为971040行!
# 写入完成
# ==*40
# SZ399357
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399357-受影响行数为971040行!
# 写入完成
# ==*40
# SZ399358
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399358-受影响行数为941040行!
# 写入完成
# ==*40
# SZ399359
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399359-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399360
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399360-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399361
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399361-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399362
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399362-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399363
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399363-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399364
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399364-受影响行数为848160行!
# 写入完成
# ==*40
# SZ399365
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399365-受影响行数为833520行!
# 写入完成
# ==*40
# SZ399366
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399366-受影响行数为833520行!
# 写入完成
# ==*40
# SZ399367
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399367-受影响行数为833520行!
# 写入完成
# ==*40
# SZ399368
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399368-受影响行数为833520行!
# 写入完成
# ==*40
# SZ399369
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399369-受影响行数为833520行!
# 写入完成
# ==*40
# SZ399370
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399370-受影响行数为823440行!
# 写入完成
# ==*40
# SZ399371
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399371-受影响行数为823440行!
# 写入完成
# ==*40
# SZ399372
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399372-受影响行数为823440行!
# 写入完成
# ==*40
# SZ399373
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399373-受影响行数为823440行!
# 写入完成
# ==*40
# SZ399374
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399374-受影响行数为823440行!
# 写入完成
# ==*40
# SZ399375
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399375-受影响行数为823440行!
# 写入完成
# ==*40
# SZ399376
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399376-受影响行数为823440行!
# 写入完成
# ==*40
# SZ399377
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399377-受影响行数为823440行!
# 写入完成
# ==*40
# SZ399378
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399378-受影响行数为781440行!
# 写入完成
# ==*40
# SZ399379
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399379-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399380
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399380-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399381
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399381-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399382
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399382-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399383
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399383-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399384
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399384-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399385
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399385-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399386
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399386-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399387
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399387-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399388
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399388-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399389
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399389-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399390
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399390-受影响行数为711840行!
# 写入完成
# ==*40
# SZ399391
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399391-受影响行数为694080行!
# 写入完成
# ==*40
# SZ399392
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399392-受影响行数为693600行!
# 写入完成
# ==*40
# SZ399393
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399393-受影响行数为670320行!
# 写入完成
# ==*40
# SZ399394
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399394-受影响行数为659520行!
# 写入完成
# ==*40
# SZ399395
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399395-受影响行数为659520行!
# 写入完成
# ==*40
# SZ399396
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399396-受影响行数为659520行!
# 写入完成
# ==*40
# SZ399397
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399397-受影响行数为657360行!
# 写入完成
# ==*40
# SZ399398
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399398-受影响行数为655920行!
# 写入完成
# ==*40
# SZ399399
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399399-受影响行数为654960行!
# 写入完成
# ==*40
# SZ399400
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399400-受影响行数为636960行!
# 写入完成
# ==*40
# SZ399401
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399401-受影响行数为636960行!
# 写入完成
# ==*40
# SZ399402
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399402-受影响行数为602640行!
# 写入完成
# ==*40
# SZ399403
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399403-受影响行数为602640行!
# 写入完成
# ==*40
# SZ399404
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399404-受影响行数为595920行!
# 写入完成
# ==*40
# SZ399405
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399405-受影响行数为595920行!
# 写入完成
# ==*40
# SZ399406
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399406-受影响行数为595920行!
# 写入完成
# ==*40
# SZ399407
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399407-受影响行数为595920行!
# 写入完成
# ==*40
# SZ399408
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399408-受影响行数为595920行!
# 写入完成
# ==*40
# SZ399409
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399409-受影响行数为595920行!
# 写入完成
# ==*40
# SZ399410
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399410-受影响行数为594720行!
# 写入完成
# ==*40
# SZ399411
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399411-受影响行数为576000行!
# 写入完成
# ==*40
# SZ399412
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399412-受影响行数为570240行!
# 写入完成
# ==*40
# SZ399413
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399413-受影响行数为552960行!
# 写入完成
# ==*40
# SZ399415
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399415-受影响行数为550320行!
# 写入完成
# ==*40
# SZ399416
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399416-受影响行数为550320行!
# 写入完成
# ==*40
# SZ399417
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399417-受影响行数为548400行!
# 写入完成
# ==*40
# SZ399418
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399418-受影响行数为539520行!
# 写入完成
# ==*40
# SZ399419
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399419-受影响行数为536400行!
# 写入完成
# ==*40
# SZ399420
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399420-受影响行数为536400行!
# 写入完成
# ==*40
# SZ399423
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399423-受影响行数为527040行!
# 写入完成
# ==*40
# SZ399427
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399427-受影响行数为525120行!
# 写入完成
# ==*40
# SZ399428
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399428-受影响行数为525120行!
# 写入完成
# ==*40
# SZ399429
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399429-受影响行数为531840行!
# 写入完成
# ==*40
# SZ399431
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399431-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399432
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399432-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399433
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399433-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399434
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399434-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399435
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399435-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399436
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399436-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399437
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399437-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399438
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399438-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399439
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399439-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399440
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399440-受影响行数为533040行!
# 写入完成
# ==*40
# SZ399441
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399441-受影响行数为529920行!
# 写入完成
# ==*40
# SZ399481
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399481-受影响行数为1115040行!
# 写入完成
# ==*40
# SZ399550
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399550-受影响行数为682800行!
# 写入完成
# ==*40
# SZ399551
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399551-受影响行数为624720行!
# 写入完成
# ==*40
# SZ399552
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399552-受影响行数为624720行!
# 写入完成
# ==*40
# SZ399553
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399553-受影响行数为624720行!
# 写入完成
# ==*40
# SZ399554
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399554-受影响行数为624720行!
# 写入完成
# ==*40
# SZ399555
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399555-受影响行数为624720行!
# 写入完成
# ==*40
# SZ399556
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399556-受影响行数为566880行!
# 写入完成
# ==*40
# SZ399557
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399557-受影响行数为566880行!
# 写入完成
# ==*40
# SZ399602
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399602-受影响行数为801120行!
# 写入完成
# ==*40
# SZ399604
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399604-受影响行数为801120行!
# 写入完成
# ==*40
# SZ399606
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399606-受影响行数为799680行!
# 写入完成
# ==*40
# SZ399608
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399608-受影响行数为778560行!
# 写入完成
# ==*40
# SZ399610
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399610-受影响行数为774960行!
# 写入完成
# ==*40
# SZ399611
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399611-受影响行数为729840行!
# 写入完成
# ==*40
# SZ399612
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399612-受影响行数为757200行!
# 写入完成
# ==*40
# SZ399613
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399613-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399614
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399614-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399615
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399615-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399616
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399616-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399617
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399617-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399618
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399618-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399619
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399619-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399620
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399620-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399621
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399621-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399622
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399622-受影响行数为739680行!
# 写入完成
# ==*40
# SZ399623
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399623-受影响行数为732960行!
# 写入完成
# ==*40
# SZ399624
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399624-受影响行数为729360行!
# 写入完成
# ==*40
# SZ399625
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399625-受影响行数为729360行!
# 写入完成
# ==*40
# SZ399626
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399626-受影响行数为729360行!
# 写入完成
# ==*40
# SZ399627
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399627-受影响行数为729360行!
# 写入完成
# ==*40
# SZ399628
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399628-受影响行数为726240行!
# 写入完成
# ==*40
# SZ399629
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399629-受影响行数为726240行!
# 写入完成
# ==*40
# SZ399630
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399630-受影响行数为726240行!
# 写入完成
# ==*40
# SZ399631
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399631-受影响行数为726240行!
# 写入完成
# ==*40
# SZ399632
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399632-受影响行数为717840行!
# 写入完成
# ==*40
# SZ399633
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399633-受影响行数为717840行!
# 写入完成
# ==*40
# SZ399634
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399634-受影响行数为717840行!
# 写入完成
# ==*40
# SZ399635
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399635-受影响行数为717840行!
# 写入完成
# ==*40
# SZ399636
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399636-受影响行数为714960行!
# 写入完成
# ==*40
# SZ399637
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399637-受影响行数为714960行!
# 写入完成
# ==*40
# SZ399638
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399638-受影响行数为714960行!
# 写入完成
# ==*40
# SZ399639
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399639-受影响行数为714960行!
# 写入完成
# ==*40
# SZ399640
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399640-受影响行数为704880行!
# 写入完成
# ==*40
# SZ399641
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399641-受影响行数为703200行!
# 写入完成
# ==*40
# SZ399642
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399642-受影响行数为703200行!
# 写入完成
# ==*40
# SZ399643
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399643-受影响行数为703200行!
# 写入完成
# ==*40
# SZ399644
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399644-受影响行数为694080行!
# 写入完成
# ==*40
# SZ399645
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399645-受影响行数为681840行!
# 写入完成
# ==*40
# SZ399646
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399646-受影响行数为672720行!
# 写入完成
# ==*40
# SZ399647
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399647-受影响行数为672720行!
# 写入完成
# ==*40
# SZ399648
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399648-受影响行数为672240行!
# 写入完成
# ==*40
# SZ399649
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399649-受影响行数为670320行!
# 写入完成
# ==*40
# SZ399650
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399650-受影响行数为670320行!
# 写入完成
# ==*40
# SZ399651
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399651-受影响行数为670320行!
# 写入完成
# ==*40
# SZ399652
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399652-受影响行数为665520行!
# 写入完成
# ==*40
# SZ399653
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399653-受影响行数为664080行!
# 写入完成
# ==*40
# SZ399654
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399654-受影响行数为657360行!
# 写入完成
# ==*40
# SZ399655
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399655-受影响行数为655920行!
# 写入完成
# ==*40
# SZ399656
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399656-受影响行数为655920行!
# 写入完成
# ==*40
# SZ399657
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399657-受影响行数为655920行!
# 写入完成
# ==*40
# SZ399658
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399658-受影响行数为655920行!
# 写入完成
# ==*40
# SZ399659
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399659-受影响行数为654960行!
# 写入完成
# ==*40
# SZ399660
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399660-受影响行数为654960行!
# 写入完成
# ==*40
# SZ399661
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399661-受影响行数为650400行!
# 写入完成
# ==*40
# SZ399662
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399662-受影响行数为650400行!
# 写入完成
# ==*40
# SZ399663
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399663-受影响行数为650400行!
# 写入完成
# ==*40
# SZ399664
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399664-受影响行数为650400行!
# 写入完成
# ==*40
# SZ399665
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399665-受影响行数为650400行!
# 写入完成
# ==*40
# SZ399666
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399666-受影响行数为650400行!
# 写入完成
# ==*40
# SZ399667
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399667-受影响行数为648240行!
# 写入完成
# ==*40
# SZ399668
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399668-受影响行数为648240行!
# 写入完成
# ==*40
# SZ399669
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399669-受影响行数为622560行!
# 写入完成
# ==*40
# SZ399670
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399670-受影响行数为602640行!
# 写入完成
# ==*40
# SZ399671
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399671-受影响行数为602640行!
# 写入完成
# ==*40
# SZ399672
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399672-受影响行数为576000行!
# 写入完成
# ==*40
# SZ399673
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399673-受影响行数为564960行!
# 写入完成
# ==*40
# SZ399674
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399674-受影响行数为507840行!
# 写入完成
# ==*40
# SZ399675
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399675-受影响行数为507840行!
# 写入完成
# ==*40
# SZ399676
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399676-受影响行数为507840行!
# 写入完成
# ==*40
# SZ399677
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399677-受影响行数为507840行!
# 写入完成
# ==*40
# SZ399678
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399678-受影响行数为505920行!
# 写入完成
# ==*40
# SZ399679
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399679-受影响行数为505920行!
# 写入完成
# ==*40
# SZ399680
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399680-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399681
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399681-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399682
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399682-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399683
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399683-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399684
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399684-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399685
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399685-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399686
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399686-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399687
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399687-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399688
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399688-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399689
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399689-受影响行数为493680行!
# 写入完成
# ==*40
# SZ399690
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399690-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399691
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399691-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399692
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399692-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399693
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399693-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399694
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399694-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399695
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399695-受影响行数为395760行!
# 写入完成
# ==*40
# SZ399696
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399696-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399697
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399697-受影响行数为399120行!
# 写入完成
# ==*40
# SZ399698
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399698-受影响行数为382080行!
# 写入完成
# ==*40
# SZ399699
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399699-受影响行数为390480行!
# 写入完成
# ==*40
# SZ399701
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399701-受影响行数为803520行!
# 写入完成
# ==*40
# SZ399702
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399702-受影响行数为803520行!
# 写入完成
# ==*40
# SZ399703
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399703-受影响行数为803520行!
# 写入完成
# ==*40
# SZ399704
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399704-受影响行数为719760行!
# 写入完成
# ==*40
# SZ399705
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399705-受影响行数为719760行!
# 写入完成
# ==*40
# SZ399706
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399706-受影响行数为719760行!
# 写入完成
# ==*40
# SZ399707
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399707-受影响行数为516480行!
# 写入完成
# ==*40
# SZ399750
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399750-受影响行数为15120行!
# 写入完成
# ==*40
# SZ399802
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399802-受影响行数为640800行!
# 写入完成
# ==*40
# SZ399803
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399803-受影响行数为499200行!
# 写入完成
# ==*40
# SZ399804
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399804-受影响行数为499440行!
# 写入完成
# ==*40
# SZ399805
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399805-受影响行数为499440行!
# 写入完成
# ==*40
# SZ399806
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399806-受影响行数为499440行!
# 写入完成
# ==*40
# SZ399807
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399807-受影响行数为499440行!
# 写入完成
# ==*40
# SZ399808
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399808-受影响行数为502320行!
# 写入完成
# ==*40
# SZ399809
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399809-受影响行数为499440行!
# 写入完成
# ==*40
# SZ399810
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399810-受影响行数为498480行!
# 写入完成
# ==*40
# SZ399811
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399811-受影响行数为498480行!
# 写入完成
# ==*40
# SZ399812
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399812-受影响行数为495360行!
# 写入完成
# ==*40
# SZ399813
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399813-受影响行数为495360行!
# 写入完成
# ==*40
# SZ399814
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399814-受影响行数为495360行!
# 写入完成
# ==*40
# SZ399817
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399817-受影响行数为5040行!
# 写入完成
# ==*40
# SZ399850
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399850-受影响行数为19920行!
# 写入完成
# ==*40
# SZ399852
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399852-受影响行数为24720行!
# 写入完成
# ==*40
# SZ399901
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399901-受影响行数为809520行!
# 写入完成
# ==*40
# SZ399903
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399903-受影响行数为1035120行!
# 写入完成
# ==*40
# SZ399905
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399905-受影响行数为997200行!
# 写入完成
# ==*40
# SZ399913
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399913-受影响行数为970800行!
# 写入完成
# ==*40
# SZ399914
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399914-受影响行数为971040行!
# 写入完成
# ==*40
# SZ399928
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399928-受影响行数为853200行!
# 写入完成
# ==*40
# SZ399932
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399932-受影响行数为853200行!
# 写入完成
# ==*40
# SZ399933
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399933-受影响行数为853200行!
# 写入完成
# ==*40
# SZ399934
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399934-受影响行数为853200行!
# 写入完成
# ==*40
# SZ399935
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399935-受影响行数为853200行!
# 写入完成
# ==*40
# SZ399959
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399959-受影响行数为726720行!
# 写入完成
# ==*40
# SZ399965
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399965-受影响行数为576720行!
# 写入完成
# ==*40
# SZ399966
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399966-受影响行数为576720行!
# 写入完成
# ==*40
# SZ399967
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399967-受影响行数为576720行!
# 写入完成
# ==*40
# SZ399970
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399970-受影响行数为550320行!
# 写入完成
# ==*40
# SZ399971
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399971-受影响行数为541680行!
# 写入完成
# ==*40
# SZ399972
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399972-受影响行数为640800行!
# 写入完成
# ==*40
# SZ399973
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399973-受影响行数为541680行!
# 写入完成
# ==*40
# SZ399974
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399974-受影响行数为533280行!
# 写入完成
# ==*40
# SZ399975
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399975-受影响行数为511200行!
# 写入完成
# ==*40
# SZ399976
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399976-受影响行数为511200行!
# 写入完成
# ==*40
# SZ399982
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399982-受影响行数为740160行!
# 写入完成
# ==*40
# SZ399983
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399983-受影响行数为511200行!
# 写入完成
# ==*40
# SZ399986
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399986-受影响行数为511200行!
# 写入完成
# ==*40
# SZ399987
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399987-受影响行数为511200行!
# 写入完成
# ==*40
# SZ399989
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399989-受影响行数为511200行!
# 写入完成
# ==*40
# SZ399990
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399990-受影响行数为506400行!
# 写入完成
# ==*40
# SZ399991
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399991-受影响行数为506400行!
# 写入完成
# ==*40
# SZ399992
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399992-受影响行数为506400行!
# 写入完成
# ==*40
# SZ399993
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399993-受影响行数为506400行!
# 写入完成
# ==*40
# SZ399994
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399994-受影响行数为506400行!
# 写入完成
# ==*40
# SZ399995
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399995-受影响行数为506400行!
# 写入完成
# ==*40
# SZ399996
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399996-受影响行数为505200行!
# 写入完成
# ==*40
# SZ399997
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399997-受影响行数为506400行!
# 写入完成
# ==*40
# SZ399998
# 192.20.57.188:1min受影响行数为0行!
# 读取完成
# 开始写入
# 写入192.20.57.188:1min--SZ399998-受影响行数为506400行!
# 写入完成
# ==*40

# %%
# 优化读取
# @jit(nopython=True)  # Set "nopython" mode for best performance, equivalent to @njit
def fast_read(path):
    na_vals = ["\\N", " ", "", "NULL"]
    df_tmp = []
    count = 0
    reader = pd.read_csv(
        path,  # 文件路径
        sep=",",  # 分割符号
        chunksize=10000000,  # 每次一个快读取的数据量
        encoding="utf-8",  # 编码方式
        low_memory=False,  # 避免内存不足
        quoting=csv.QUOTE_NONE,  # 引用约定。可选值包括csv.QUOTE _ ALL (引用用所有字段）,这里是不引用
        keep_default_na=True,
        na_values=na_vals,
        iterator=True,
    )
    # nrows=10000000, # 只读一千万行)
    # low_memory : boolean, default True
    # 分块加载到内存，再低内存消耗中解析，但是可能出现类型混淆。
    # 确保类型不被混淆需要设置为False，或者使用dtype 参数指定类型。
    # 注意使用chunksize 或者iterator 参数分块读入会将整个文件读入到一个Dataframe，而忽略类型（只能在C解析器中有效）
    for chunk in reader:
        df_tmp.append(chunk)
        del chunk
        # print("the chunk " + str(count) + " has been stored...")
        # print("the mem-cost is now: ", str(sys.getsizeof(df_tmp) / (1)), "MB \n")
        count += 1
    return pd.concat(df_tmp)

# %%
a = fast_read("E:/行情/指数1分钟/000001.SH.csv")
